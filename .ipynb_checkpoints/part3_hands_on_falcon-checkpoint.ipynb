# %% [markdown]
# # Part 3: Hands-On FALCON — Watch Active Learning Happen
#
# ## What We Know (from Part 2)
# - FALCON wraps a surrogate model (GPR) around an exact calculator
# - It decides when to call DFT based on uncertainty ε
# - It clusters training data and retrains only the nearest model
# - The OTF loop runs during MD
#
# ## What We'll Do Now
# 1. **Run** a FALCON simulation on a Pt₅₅ cluster
# 2. **Observe** the training data grow in real-time
# 3. **Change** ε and see how it affects DFT calls
# 4. **Change** model_size and see how it affects training time
# 5. **Diagnose** the health of the simulation
# 6. **Predict** outcomes before running, then verify
#
# ## Baseline: The Default FALCON Simulation
#
# We'll run FALCON on a Pt₅₅ cluster at 600 K with:
# - ε = 0.10 eV (default threshold)
# - model_size = 200 (default clustering)
#
# **Before we run it, predict:**
# 1. How many DFT calls in the first 1000 MD steps?
# 2. Will the training data growth plateau?

# %%
# ============================================================
# IMPORTS
# ============================================================
import os
import time
import numpy as np
import matplotlib.pyplot as plt

from ase import units
from ase.build import bulk
from ase.calculators.emt import EMT
from ase.calculators.singlepoint import SinglePointCalculator
from ase.optimize import QuasiNewton
from ase.md.langevin import Langevin

from falcon_md.otf_calculator import FALCON
from falcon_md.models.agox_models import GPR as FalconGPR

# ============================================================
# WINDOWS PATCHES  (re-run after every kernel restart)
# ============================================================
if not hasattr(os, "sched_getaffinity"):
    os.sched_getaffinity = lambda pid: set(range(os.cpu_count() or 1))
os.environ["RAY_raylet_start_wait_time_s"] = "120"

# ============================================================
# SETUP
# ============================================================
T = 600
accuracy_e = 0.10
n_steps = 100
model_size = 200

os.makedirs("outputs", exist_ok=True)

# ============================================================
# INITIAL STRUCTURE
# ============================================================
atoms = bulk('Pt', 'fcc', a=3.92, cubic=True).repeat((3, 3, 3))
atoms.rattle(0.1)          # break symmetry so QN has work to do
exact_calc = EMT()
atoms.calc = exact_calc

# ============================================================
# GEOMETRY OPTIMIZATION FOR INITIAL TRAINING DATA
# ============================================================
training_frames = []

def collect(atoms):
    # Snapshot the current state and freeze its energy/forces into a
    # SinglePointCalculator, so AGOX's EnergyFilter can call
    # get_potential_energy() on each frame later.
    frame = atoms.copy()
    frame.calc = SinglePointCalculator(
        frame,
        energy=atoms.get_potential_energy(),
        forces=atoms.get_forces(),
    )
    training_frames.append(frame)

qn = QuasiNewton(atoms, logfile="outputs/opt_baseline.log")
qn.attach(collect, interval=1, atoms=atoms)
qn.run(fmax=0.05, steps=20)

training_data = training_frames
print(f"Initial training data: {len(training_data)} structures")

# ============================================================
# FALCON CALCULATOR
# ============================================================
atoms.calc = FALCON(
    model=FalconGPR(atoms),   # FALCON's GPR wrapper (use_ray=True)
    calc=exact_calc,          # signature uses `calc`, not `exact_calc`
    training_data=training_data,
    accuracy_e=accuracy_e,    # signature uses `accuracy_e`, not `accuracy`
    modelsize=model_size,     # signature uses `modelsize`, not `model_size`
    train_log=False,
)

# ============================================================
# RUN MD & TRACK
# ============================================================
energies = []
n_training_at_step = []
n_atoms = len(atoms)

dyn = Langevin(
    atoms,
    1 * units.fs,
    temperature_K=T,
    friction=0.002,
    trajectory="outputs/md_baseline.traj",
    logfile="outputs/md_baseline.log",
)

print(f"Running FALCON OTF-MD: T={T} K, ε={accuracy_e} eV, "
      f"modelsize={model_size}")
print(f"System: {n_atoms} atoms, {n_steps} MD steps")
print()

t_start = time.time()

for step in range(n_steps):
    dyn.run(1)
    energies.append(atoms.get_potential_energy())
    n_training_at_step.append(len(atoms.calc.training_data))

t_total = time.time() - t_start

print("Simulation complete!")
print(f"  Total wall time: {t_total:.1f} s")
print(f"  Final training structures: {len(atoms.calc.training_data)}")
print(f"  Final energy: {energies[-1]:.4f} eV")
# Out:
# Initial training data: 9 structures
# Using C:\Users\carli/tmp/ray as Ray temporary folder because the given or generated path is too long.
# 2026-09-23 09:12:07,143	INFO worker.py:2024 -- Started a local Ray instance.
# Ray Resources
# 	CPU = 12.0
# 	memory = 24000000000.0
# 	node:127.0.0.1 = 1.0
# 	object_store_memory = 6000000000.0
# 	node:__internal_head__ = 1.0
# (raylet) Stack (most recent call first):
# (raylet)   File "C:\Users\carli\AppData\Local\miniconda\envs\ci\Lib\site-packages\ray\_private\worker.py", line 627 in job_logging_config
# (raylet)   File "C:\Users\carli\AppData\Local\miniconda\envs\ci\Lib\site-packages\ray\_private\worker.py", line 2807 in disconnect
# (raylet)   File "C:\Users\carli\AppData\Local\miniconda\envs\ci\Lib\site-packages\ray\_private\worker.py", line 2118 in shutdown
# (raylet)   File "C:\Users\carli\AppData\Local\miniconda\envs\ci\Lib\site-packages\ray\_private\worker.py", line 1170 in wrapper
# (raylet)   File "C:\Users\carli\AppData\Local\miniconda\envs\ci\Lib\site-packages\ray\_private\client_mode_hook.py", line 134 in wrapper
# Attempt 0: Pool started successfully.
#
# You are using the Gaussian Process Regression model implemented in AGOX. If you use this model in a publication, please cite:
# Mads-Peter V. Christiansen, Nikolaj Rønne, Bjørk Hammer, "Atomistic Global Optimization X: A Python package for optimization of atomistic structures", J. Chem. Phys. 157, 054701 (2022),
# <https://arxiv.org/abs/2204.01451>
#
# If you are using FALCON in a publication, please cite:
#  Felis, N., Dononelli, W. (2025). FALCON: fast active learning for machine learning potentials in atomistic and ab initio molecular dynamics simulations. npj Comput. Mater., https://doi.org/10.1038/s41524-025-01897-8
# Running FALCON OTF-MD: T=600 K, ε=0.1 eV, modelsize=200
# System: 108 atoms, 100 MD steps
#
#
# ============================ Step: 1 ============================
#
# Total structures in training data: 9
# 1 active Models.
# (9, 1, 60)
# C:\Users\carli\AppData\Local\miniconda\envs\ci\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\carli\AppData\Local\miniconda\envs\ci\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\carli\AppData\Local\miniconda\envs\ci\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\carli\AppData\Local\miniconda\envs\ci\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\carli\AppData\Local\miniconda\envs\ci\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# C:\Users\carli\AppData\Local\miniconda\envs\ci\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# [0 0 0 0 0 0 0 0 0]
# Cluster 0 contains 9 objects.
# Clustering of 9 took 5.040292263031006 s.
# <class 'agox.models.GPR.GPR.GPR'>
# Updating attributes: ['X', 'Y']
# Updated 2 attributes on Ray Actors in 0.06 s.
# Updating attributes: ['alpha', 'K_inv', 'kernel', 'K', 'mean_energy',
# '_ready_state']
# Updated 6 attributes on Ray Actors in 0.08 s.
# ------ Model Info ------
# Descriptor:
#     Fingerprint
# Kernel:
#     12.3**2 * 0.1**2 * RBF(length_scale=0.205) + 0.995**2 *
# RBF(length_scale=0.94) + Noise(noise_level=0.01)
# Filter:
#     EnergyFilter removed 0 structures
#     - Data before filter: 9
#     - Data after filter: 9
# ------ Training Info ------
# Training data size: 9
# Neg. log marginal likelihood.: 6.29
# Hyperparameter optimizations: 12
# Model 0 trained with 9 structures (5.1471405029296875 s).
#
# Model trained with initial training data. (5.150018215179443 s)
#
# Model 0...
# Predict energy (0.451188325881958 s)
# Predict energy_uncertainty (0.3899376392364502 s)
# Predict forces (1.1772363185882568 s)
# Predict forces_uncertainty (1.7510459423065186 s)
# E = -0.020112603331505774 (Model 0)
# Estd = 0.052926232630078 (Model 0)
# F = 0.03132366315905731 (Model 0)
# Fstd = 0.006609651883670828 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.020112603331505774
# Estd = 0.052926232630078
# Fmax = 0.03132366315905731
# Fstd = 0.006609651883670828
#
# Exact calculation...
# Exact Calculation (0.002016782760620117 s)
# Real energy = -0.01183234842712011
# Real Fmax = 0.031187058244214094
# New structure is added to Model 0.
#
# Step 1: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 2 ============================
#
# Total structures in training data: 10
# Model 0...
# Predict energy (0.3751544952392578 s)
# Predict energy_uncertainty (0.33836913108825684 s)
# Predict forces (1.2826817035675049 s)
# Predict forces_uncertainty (1.7271792888641357 s)
# E = -0.02011420000848707 (Model 0)
# Estd = 0.05292686004977962 (Model 0)
# F = 0.031039273744700703 (Model 0)
# Fstd = 0.006588132429555852 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.02011420000848707
# Estd = 0.05292686004977962
# Fmax = 0.031039273744700703
# Fstd = 0.006588132429555852
#
# Exact calculation...
# Exact Calculation (0.04015970230102539 s)
# Real energy = -0.011833673365092778
# Real Fmax = 0.03093427173478423
# New structure is added to Model 0.
#
# Step 2: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 3 ============================
#
# Total structures in training data: 11
# Model 0...
# Predict energy (0.37200093269348145 s)
# Predict energy_uncertainty (0.3566911220550537 s)
# Predict forces (1.289133071899414 s)
# Predict forces_uncertainty (1.6922738552093506 s)
# E = -0.020115448952778614 (Model 0)
# Estd = 0.05292865098767633 (Model 0)
# F = 0.03050736078246349 (Model 0)
# Fstd = 0.006545040137208367 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.020115448952778614
# Estd = 0.05292865098767633
# Fmax = 0.03050736078246349
# Fstd = 0.006545040137208367
#
# Exact calculation...
# Exact Calculation (0.05043220520019531 s)
# Real energy = -0.011833756725788902
# Real Fmax = 0.030461851224183722
# New structure is added to Model 0.
#
# Step 3: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 4 ============================
#
# Total structures in training data: 12
# Model 0...
# Predict energy (0.3781740665435791 s)
# Predict energy_uncertainty (0.33144474029541016 s)
# Predict forces (1.423814058303833 s)
# Predict forces_uncertainty (1.6523044109344482 s)
# E = -0.020110147241685805 (Model 0)
# Estd = 0.0529304525019506 (Model 0)
# F = 0.029924034574084962 (Model 0)
# Fstd = 0.006498879387692375 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.020110147241685805
# Estd = 0.0529304525019506
# Fmax = 0.029924034574084962
# Fstd = 0.006498879387692375
#
# Exact calculation...
# Exact Calculation (0.04073739051818848 s)
# Real energy = -0.011826512863102323
# Real Fmax = 0.02998819794243707
# New structure is added to Model 0.
#
# Step 4: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 5 ============================
#
# Total structures in training data: 13
# Model 0...
# Predict energy (0.49369263648986816 s)
# Predict energy_uncertainty (0.6743752956390381 s)
# Predict forces (1.7793142795562744 s)
# Predict forces_uncertainty (1.8678195476531982 s)
# E = -0.020099730433550178 (Model 0)
# Estd = 0.05293237714230235 (Model 0)
# F = 0.029516617153713995 (Model 0)
# Fstd = 0.006414154057005812 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.020099730433550178
# Estd = 0.05293237714230235
# Fmax = 0.029516617153713995
# Fstd = 0.006414154057005812
#
# Exact calculation...
# Exact Calculation (0.041040897369384766 s)
# Real energy = -0.011813746402889791
# Real Fmax = 0.030320689048112328
# New structure is added to Model 0.
#
# Step 5: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 6 ============================
#
# Total structures in training data: 14
# Model 0...
# Predict energy (0.4824948310852051 s)
# Predict energy_uncertainty (0.4637181758880615 s)
# Predict forces (1.4333562850952148 s)
# Predict forces_uncertainty (1.8803954124450684 s)
# E = -0.02007552158038184 (Model 0)
# Estd = 0.05293385271190753 (Model 0)
# F = 0.03029494167784752 (Model 0)
# Fstd = 0.0063281042049060975 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.02007552158038184
# Estd = 0.05293385271190753
# Fmax = 0.03029494167784752
# Fstd = 0.0063281042049060975
#
# Exact calculation...
# Exact Calculation (0.04087090492248535 s)
# Real energy = -0.011786988936151488
# Real Fmax = 0.031229635235290695
# New structure is added to Model 0.
#
# Step 6: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 7 ============================
#
# Total structures in training data: 15
# Model 0...
# Predict energy (0.45427417755126953 s)
# Predict energy_uncertainty (0.4568774700164795 s)
# Predict forces (1.4878034591674805 s)
# Predict forces_uncertainty (2.124643325805664 s)
# E = -0.020036973482302933 (Model 0)
# Estd = 0.05293458644310032 (Model 0)
# F = 0.031028991397964712 (Model 0)
# Fstd = 0.0063182514213837755 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.020036973482302933
# Estd = 0.05293458644310032
# Fmax = 0.031028991397964712
# Fstd = 0.0063182514213837755
#
# Exact calculation...
# Exact Calculation (0.031525611877441406 s)
# Real energy = -0.011745882921026407
# Real Fmax = 0.03211668916142451
# New structure is added to Model 0.
#
# Step 7: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 8 ============================
#
# Total structures in training data: 16
# Model 0...
# Predict energy (0.4293501377105713 s)
# Predict energy_uncertainty (0.40415287017822266 s)
# Predict forces (1.4474620819091797 s)
# Predict forces_uncertainty (1.9319591522216797 s)
# E = -0.019981129893714034 (Model 0)
# Estd = 0.05293366313328818 (Model 0)
# F = 0.03157235155637975 (Model 0)
# Fstd = 0.006352687146980706 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.019981129893714034
# Estd = 0.05293366313328818
# Fmax = 0.03157235155637975
# Fstd = 0.006352687146980706
#
# Exact calculation...
# Exact Calculation (0.06540536880493164 s)
# Real energy = -0.011687485202763526
# Real Fmax = 0.032806280920095396
# New structure is added to Model 0.
#
# Step 8: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 9 ============================
#
# Total structures in training data: 17
# Model 0...
# Predict energy (0.4524095058441162 s)
# Predict energy_uncertainty (0.4230382442474365 s)
# Predict forces (1.4422173500061035 s)
# Predict forces_uncertainty (1.690582513809204 s)
# E = -0.019907163894718582 (Model 0)
# Estd = 0.052932472401408505 (Model 0)
# F = 0.03216632914328158 (Model 0)
# Fstd = 0.006404988983486524 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.019907163894718582
# Estd = 0.052932472401408505
# Fmax = 0.03216632914328158
# Fstd = 0.006404988983486524
#
# Exact calculation...
# Exact Calculation (0.04149436950683594 s)
# Real energy = -0.011610485425116224
# Real Fmax = 0.03352835458772519
# New structure is added to Model 0.
#
# Step 9: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 10 ============================
#
# Total structures in training data: 18
# Model 0...
# Predict energy (0.6000723838806152 s)
# Predict energy_uncertainty (0.5926022529602051 s)
# Predict forces (1.7895855903625488 s)
# Predict forces_uncertainty (1.8157742023468018 s)
# E = -0.019806621006573266 (Model 0)
# Estd = 0.05292926989396523 (Model 0)
# F = 0.03291910851796514 (Model 0)
# Fstd = 0.006468939835665255 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.019806621006573266
# Estd = 0.05292926989396523
# Fmax = 0.03291910851796514
# Fstd = 0.006468939835665255
#
# Exact calculation...
# Exact Calculation (0.0316929817199707 s)
# Real energy = -0.011506724677840197
# Real Fmax = 0.03509751312544333
# New structure is added to Model 0.
# Updating attributes: ['X', 'Y']
# Updated 2 attributes on Ray Actors in 0.03 s.
# Updating attributes: ['alpha', 'K_inv', 'kernel', 'K', 'mean_energy',
# '_ready_state']
# Updated 6 attributes on Ray Actors in 0.03 s.
# ------ Model Info ------
# Descriptor:
#     Fingerprint
# Kernel:
#     13**2 * 0.1**2 * RBF(length_scale=0.216) + 0.995**2 *
# RBF(length_scale=0.976) + Noise(noise_level=0.01)
# Filter:
#     EnergyFilter removed 0 structures
#     - Data before filter: 19
#     - Data after filter: 19
# ------ Training Info ------
# Training data size: 19
# Neg. log marginal likelihood.: -6.78
# Hyperparameter optimizations: 12
# Step 10: Model 0 trained with 19 Structures (9.198065519332886 s). (1 Training steps.)
#
#
# ============================ Step: 11 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.6027500629425049 s)
# Predict energy_uncertainty (0.4622323513031006 s)
# Predict forces (1.3214263916015625 s)
# Predict forces_uncertainty (1.6755578517913818 s)
# E = -0.013692078621554415 (Model 0)
# Estd = 0.02714628819341951 (Model 0)
# F = 0.0363035620475701 (Model 0)
# Fstd = 0.00339992738558389 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.013692078621554415
# Estd = 0.02714628819341951
# Fmax = 0.0363035620475701
# Fstd = 0.00339992738558389
#
# Step 11: Model not trained.
#
#
# ============================ Step: 12 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3854963779449463 s)
# Predict energy_uncertainty (0.3485736846923828 s)
# Predict forces (1.340015172958374 s)
# Predict forces_uncertainty (1.7069761753082275 s)
# E = -0.013526420967129749 (Model 0)
# Estd = 0.02714387636922941 (Model 0)
# F = 0.038279774139079605 (Model 0)
# Fstd = 0.0034697137270013963 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.013526420967129749
# Estd = 0.02714387636922941
# Fmax = 0.038279774139079605
# Fstd = 0.0034697137270013963
#
# Step 12: Model not trained.
#
#
# ============================ Step: 13 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3511207103729248 s)
# Predict energy_uncertainty (0.33475327491760254 s)
# Predict forces (1.3423075675964355 s)
# Predict forces_uncertainty (1.5538630485534668 s)
# E = -0.013331850382325983 (Model 0)
# Estd = 0.027141487889403737 (Model 0)
# F = 0.0402213068874342 (Model 0)
# Fstd = 0.003573397532726535 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.013331850382325983
# Estd = 0.027141487889403737
# Fmax = 0.0402213068874342
# Fstd = 0.003573397532726535
#
# Step 13: Model not trained.
#
#
# ============================ Step: 14 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.4546775817871094 s)
# Predict energy_uncertainty (0.3535194396972656 s)
# Predict forces (1.20656156539917 s)
# Predict forces_uncertainty (1.6456868648529053 s)
# E = -0.013108639807267064 (Model 0)
# Estd = 0.027138622516193308 (Model 0)
# F = 0.04190702903574351 (Model 0)
# Fstd = 0.0036722909925306444 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.013108639807267064
# Estd = 0.027138622516193308
# Fmax = 0.04190702903574351
# Fstd = 0.0036722909925306444
#
# Step 14: Model not trained.
#
#
# ============================ Step: 15 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3694140911102295 s)
# Predict energy_uncertainty (0.3414492607116699 s)
# Predict forces (1.1353261470794678 s)
# Predict forces_uncertainty (1.5779292583465576 s)
# E = -0.0128496920688429 (Model 0)
# Estd = 0.027135640531742167 (Model 0)
# F = 0.04352606286902319 (Model 0)
# Fstd = 0.003793979513236388 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.0128496920688429
# Estd = 0.027135640531742167
# Fmax = 0.04352606286902319
# Fstd = 0.003793979513236388
#
# Step 15: Model not trained.
#
#
# ============================ Step: 16 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3663313388824463 s)
# Predict energy_uncertainty (0.39160585403442383 s)
# Predict forces (1.2709126472473145 s)
# Predict forces_uncertainty (1.6306350231170654 s)
# E = -0.012556225961714351 (Model 0)
# Estd = 0.02713298543694263 (Model 0)
# F = 0.046248909670689835 (Model 0)
# Fstd = 0.003940080579411734 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.012556225961714351
# Estd = 0.02713298543694263
# Fmax = 0.046248909670689835
# Fstd = 0.003940080579411734
#
# Step 16: Model not trained.
#
#
# ============================ Step: 17 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3983187675476074 s)
# Predict energy_uncertainty (0.3641202449798584 s)
# Predict forces (1.3040573596954346 s)
# Predict forces_uncertainty (1.9509632587432861 s)
# E = -0.012219686966882026 (Model 0)
# Estd = 0.02713079625151829 (Model 0)
# F = 0.05002571718789306 (Model 0)
# Fstd = 0.004103441627327517 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.012219686966882026
# Estd = 0.02713079625151829
# Fmax = 0.05002571718789306
# Fstd = 0.004103441627327517
#
# Step 17: Model not trained.
#
#
# ============================ Step: 18 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.46213269233703613 s)
# Predict energy_uncertainty (0.2558448314666748 s)
# Predict forces (0.8070733547210693 s)
# Predict forces_uncertainty (1.2826313972473145 s)
# E = -0.011838137893412704 (Model 0)
# Estd = 0.027128906970645194 (Model 0)
# F = 0.05399361316170962 (Model 0)
# Fstd = 0.004283810499795474 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.011838137893412704
# Estd = 0.027128906970645194
# Fmax = 0.05399361316170962
# Fstd = 0.004283810499795474
#
# Step 18: Model not trained.
#
#
# ============================ Step: 19 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.29997968673706055 s)
# Predict energy_uncertainty (0.18844938278198242 s)
# Predict forces (0.5354604721069336 s)
# Predict forces_uncertainty (0.716029167175293 s)
# E = -0.01139725845616213 (Model 0)
# Estd = 0.027126859124639136 (Model 0)
# F = 0.058028902793405106 (Model 0)
# Fstd = 0.0044973728797431676 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.01139725845616213
# Estd = 0.027126859124639136
# Fmax = 0.058028902793405106
# Fstd = 0.0044973728797431676
#
# Step 19: Model not trained.
#
#
# ============================ Step: 20 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.18812346458435059 s)
# Predict energy_uncertainty (0.13129734992980957 s)
# Predict forces (0.5342211723327637 s)
# Predict forces_uncertainty (0.6506547927856445 s)
# E = -0.010896040372673998 (Model 0)
# Estd = 0.027125896840114246 (Model 0)
# F = 0.06224538741815573 (Model 0)
# Fstd = 0.004743274167567872 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.010896040372673998
# Estd = 0.027125896840114246
# Fmax = 0.06224538741815573
# Fstd = 0.004743274167567872
#
# Step 20: Model not trained.
#
#
# ============================ Step: 21 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.13684773445129395 s)
# Predict energy_uncertainty (0.13754796981811523 s)
# Predict forces (0.3838212490081787 s)
# Predict forces_uncertainty (0.60498046875 s)
# E = -0.010345459405643798 (Model 0)
# Estd = 0.027126441131947534 (Model 0)
# F = 0.06625870053391503 (Model 0)
# Fstd = 0.005015554978848622 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.010345459405643798
# Estd = 0.027126441131947534
# Fmax = 0.06625870053391503
# Fstd = 0.005015554978848622
#
# Step 21: Model not trained.
#
#
# ============================ Step: 22 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.13690471649169922 s)
# Predict energy_uncertainty (0.1471548080444336 s)
# Predict forces (0.762671947479248 s)
# Predict forces_uncertainty (1.4849348068237305 s)
# E = -0.00972659879954585 (Model 0)
# Estd = 0.027129381801023634 (Model 0)
# F = 0.06999625412537235 (Model 0)
# Fstd = 0.005321283526344498 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.00972659879954585
# Estd = 0.027129381801023634
# Fmax = 0.06999625412537235
# Fstd = 0.005321283526344498
#
# Step 22: Model not trained.
#
#
# ============================ Step: 23 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.4089360237121582 s)
# Predict energy_uncertainty (0.46825504302978516 s)
# Predict forces (1.6019084453582764 s)
# Predict forces_uncertainty (2.057957649230957 s)
# E = -0.009045426479640684 (Model 0)
# Estd = 0.027134997955193606 (Model 0)
# F = 0.07351636735347492 (Model 0)
# Fstd = 0.005655330538285792 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.009045426479640684
# Estd = 0.027134997955193606
# Fmax = 0.07351636735347492
# Fstd = 0.005655330538285792
#
# Step 23: Model not trained.
#
#
# ============================ Step: 24 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.4514944553375244 s)
# Predict energy_uncertainty (0.42578125 s)
# Predict forces (1.2945334911346436 s)
# Predict forces_uncertainty (1.5355186462402344 s)
# E = -0.008296630063686194 (Model 0)
# Estd = 0.027144115122515588 (Model 0)
# F = 0.07694050432740565 (Model 0)
# Fstd = 0.00601906216000588 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.008296630063686194
# Estd = 0.027144115122515588
# Fmax = 0.07694050432740565
# Fstd = 0.00601906216000588
#
# Step 24: Model not trained.
#
#
# ============================ Step: 25 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.36000823974609375 s)
# Predict energy_uncertainty (0.32704949378967285 s)
# Predict forces (1.2429769039154053 s)
# Predict forces_uncertainty (1.6185829639434814 s)
# E = -0.007461839103681922 (Model 0)
# Estd = 0.02715688096444826 (Model 0)
# F = 0.08059423029024096 (Model 0)
# Fstd = 0.006405558925749441 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.007461839103681922
# Estd = 0.02715688096444826
# Fmax = 0.08059423029024096
# Fstd = 0.006405558925749441
#
# Step 25: Model not trained.
#
#
# ============================ Step: 26 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.42681288719177246 s)
# Predict energy_uncertainty (0.3155975341796875 s)
# Predict forces (1.1471145153045654 s)
# Predict forces_uncertainty (1.4696128368377686 s)
# E = -0.006549530235534284 (Model 0)
# Estd = 0.02717497958531214 (Model 0)
# F = 0.08435853655066644 (Model 0)
# Fstd = 0.006818091894598348 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.006549530235534284
# Estd = 0.02717497958531214
# Fmax = 0.08435853655066644
# Fstd = 0.006818091894598348
#
# Step 26: Model not trained.
#
#
# ============================ Step: 27 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.33727192878723145 s)
# Predict energy_uncertainty (0.35333871841430664 s)
# Predict forces (1.1711254119873047 s)
# Predict forces_uncertainty (1.685121774673462 s)
# E = -0.005561856850521574 (Model 0)
# Estd = 0.027198391280433096 (Model 0)
# F = 0.08767883170679333 (Model 0)
# Fstd = 0.00737197080127997 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.005561856850521574
# Estd = 0.027198391280433096
# Fmax = 0.08767883170679333
# Fstd = 0.00737197080127997
#
# Step 27: Model not trained.
#
#
# ============================ Step: 28 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.34123682975769043 s)
# Predict energy_uncertainty (0.30702853202819824 s)
# Predict forces (1.315958023071289 s)
# Predict forces_uncertainty (1.7123408317565918 s)
# E = -0.004488409991494358 (Model 0)
# Estd = 0.027229263788246152 (Model 0)
# F = 0.09084730334636228 (Model 0)
# Fstd = 0.00807720821973849 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.004488409991494358
# Estd = 0.027229263788246152
# Fmax = 0.09084730334636228
# Fstd = 0.00807720821973849
#
# Step 28: Model not trained.
#
#
# ============================ Step: 29 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3876488208770752 s)
# Predict energy_uncertainty (0.3713099956512451 s)
# Predict forces (1.3835961818695068 s)
# Predict forces_uncertainty (1.6347055435180664 s)
# E = -0.0033429366372329516 (Model 0)
# Estd = 0.027268875569625633 (Model 0)
# F = 0.09361363380071214 (Model 0)
# Fstd = 0.008891622115402158 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.0033429366372329516
# Estd = 0.027268875569625633
# Fmax = 0.09361363380071214
# Fstd = 0.008891622115402158
#
# Step 29: Model not trained.
#
#
# ============================ Step: 30 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.44805359840393066 s)
# Predict energy_uncertainty (0.38199782371520996 s)
# Predict forces (1.2573745250701904 s)
# Predict forces_uncertainty (1.666027545928955 s)
# E = -0.0021500936936287296 (Model 0)
# Estd = 0.02731762653739681 (Model 0)
# F = 0.09626624172763483 (Model 0)
# Fstd = 0.009780978358305615 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.0021500936936287296
# Estd = 0.02731762653739681
# Fmax = 0.09626624172763483
# Fstd = 0.009780978358305615
#
# Step 30: Model not trained.
#
#
# ============================ Step: 31 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.37041234970092773 s)
# Predict energy_uncertainty (0.38161778450012207 s)
# Predict forces (1.3340280055999756 s)
# Predict forces_uncertainty (1.6274118423461914 s)
# E = -0.0008931451776501564 (Model 0)
# Estd = 0.02737535877364341 (Model 0)
# F = 0.09895778958332964 (Model 0)
# Fstd = 0.010736568119074669 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.0008931451776501564
# Estd = 0.02737535877364341
# Fmax = 0.09895778958332964
# Fstd = 0.010736568119074669
#
# Step 31: Model not trained.
#
#
# ============================ Step: 32 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3776874542236328 s)
# Predict energy_uncertainty (0.363067626953125 s)
# Predict forces (1.288137435913086 s)
# Predict forces_uncertainty (1.5692179203033447 s)
# E = 0.00044220854620358185 (Model 0)
# Estd = 0.02744497143415498 (Model 0)
# F = 0.10137014455703666 (Model 0)
# Fstd = 0.01177373430890438 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.00044220854620358185
# Estd = 0.02744497143415498
# Fmax = 0.10137014455703666
# Fstd = 0.01177373430890438
#
# Step 32: Model not trained.
#
#
# ============================ Step: 33 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.35658907890319824 s)
# Predict energy_uncertainty (0.34346532821655273 s)
# Predict forces (1.3204970359802246 s)
# Predict forces_uncertainty (1.7026886940002441 s)
# E = 0.0018470480409367163 (Model 0)
# Estd = 0.027525819360113776 (Model 0)
# F = 0.10325034632051272 (Model 0)
# Fstd = 0.012889182420498874 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.0018470480409367163
# Estd = 0.027525819360113776
# Fmax = 0.10325034632051272
# Fstd = 0.012889182420498874
#
# Step 33: Model not trained.
#
#
# ============================ Step: 34 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.42225122451782227 s)
# Predict energy_uncertainty (0.36557626724243164 s)
# Predict forces (1.2969717979431152 s)
# Predict forces_uncertainty (1.649362325668335 s)
# E = 0.0033144025197229254 (Model 0)
# Estd = 0.027619805737692526 (Model 0)
# F = 0.10572382463710099 (Model 0)
# Fstd = 0.014099049562462496 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.0033144025197229254
# Estd = 0.027619805737692526
# Fmax = 0.10572382463710099
# Fstd = 0.014099049562462496
#
# Step 34: Model not trained.
#
#
# ============================ Step: 35 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.37273621559143066 s)
# Predict energy_uncertainty (0.3849325180053711 s)
# Predict forces (1.3085131645202637 s)
# Predict forces_uncertainty (1.677900791168213 s)
# E = 0.00486574332677292 (Model 0)
# Estd = 0.02772969707427955 (Model 0)
# F = 0.11107026978190487 (Model 0)
# Fstd = 0.015432109364075556 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.00486574332677292
# Estd = 0.02772969707427955
# Fmax = 0.11107026978190487
# Fstd = 0.015432109364075556
#
# Step 35: Model not trained.
#
#
# ============================ Step: 36 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3863186836242676 s)
# Predict energy_uncertainty (0.3546464443206787 s)
# Predict forces (1.4047300815582275 s)
# Predict forces_uncertainty (1.625596523284912 s)
# E = 0.006508807870589051 (Model 0)
# Estd = 0.027860954829553104 (Model 0)
# F = 0.1160884388733524 (Model 0)
# Fstd = 0.016889891330585334 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.006508807870589051
# Estd = 0.027860954829553104
# Fmax = 0.1160884388733524
# Fstd = 0.016889891330585334
#
# Step 36: Model not trained.
#
#
# ============================ Step: 37 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.42786550521850586 s)
# Predict energy_uncertainty (0.1491074562072754 s)
# Predict forces (0.5167853832244873 s)
# Predict forces_uncertainty (0.7997395992279053 s)
# E = 0.00821397591220241 (Model 0)
# Estd = 0.02800881449209312 (Model 0)
# F = 0.12122312139715015 (Model 0)
# Fstd = 0.018388596404508267 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.00821397591220241
# Estd = 0.02800881449209312
# Fmax = 0.12122312139715015
# Fstd = 0.018388596404508267
#
# Step 37: Model not trained.
#
#
# ============================ Step: 38 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.17301225662231445 s)
# Predict energy_uncertainty (0.16056561470031738 s)
# Predict forces (0.4120626449584961 s)
# Predict forces_uncertainty (0.5516312122344971 s)
# E = 0.009984578982876302 (Model 0)
# Estd = 0.02817133182612347 (Model 0)
# F = 0.12681784883536684 (Model 0)
# Fstd = 0.019964195792508993 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.009984578982876302
# Estd = 0.02817133182612347
# Fmax = 0.12681784883536684
# Fstd = 0.019964195792508993
#
# Step 38: Model not trained.
#
#
# ============================ Step: 39 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.13385462760925293 s)
# Predict energy_uncertainty (0.10469722747802734 s)
# Predict forces (0.40279126167297363 s)
# Predict forces_uncertainty (1.8573198318481445 s)
# E = 0.011838037374531929 (Model 0)
# Estd = 0.028355437610127272 (Model 0)
# F = 0.13290365033011184 (Model 0)
# Fstd = 0.021646941769934862 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.011838037374531929
# Estd = 0.028355437610127272
# Fmax = 0.13290365033011184
# Fstd = 0.021646941769934862
#
# Step 39: Model not trained.
#
#
# ============================ Step: 40 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3981907367706299 s)
# Predict energy_uncertainty (0.3692154884338379 s)
# Predict forces (1.405184030532837 s)
# Predict forces_uncertainty (1.7651638984680176 s)
# E = 0.013768380192746843 (Model 0)
# Estd = 0.028563368766837783 (Model 0)
# F = 0.13866483196924317 (Model 0)
# Fstd = 0.02343390270659045 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.013768380192746843
# Estd = 0.028563368766837783
# Fmax = 0.13866483196924317
# Fstd = 0.02343390270659045
#
# Step 40: Model not trained.
#
#
# ============================ Step: 41 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.4907863140106201 s)
# Predict energy_uncertainty (0.36450672149658203 s)
# Predict forces (1.3615155220031738 s)
# Predict forces_uncertainty (1.6611056327819824 s)
# E = 0.01578315855573087 (Model 0)
# Estd = 0.02879794972436535 (Model 0)
# F = 0.14420498687591524 (Model 0)
# Fstd = 0.02527850384400192 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.01578315855573087
# Estd = 0.02879794972436535
# Fmax = 0.14420498687591524
# Fstd = 0.02527850384400192
#
# Step 41: Model not trained.
#
#
# ============================ Step: 42 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.4138321876525879 s)
# Predict energy_uncertainty (0.3523573875427246 s)
# Predict forces (1.3277344703674316 s)
# Predict forces_uncertainty (1.5495820045471191 s)
# E = 0.01788534002308051 (Model 0)
# Estd = 0.029060535892299254 (Model 0)
# F = 0.14975490573481118 (Model 0)
# Fstd = 0.027505923373401114 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.01788534002308051
# Estd = 0.029060535892299254
# Fmax = 0.14975490573481118
# Fstd = 0.027505923373401114
#
# Step 42: Model not trained.
#
#
# ============================ Step: 43 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3588721752166748 s)
# Predict energy_uncertainty (0.34458160400390625 s)
# Predict forces (1.3290576934814453 s)
# Predict forces_uncertainty (1.5610466003417969 s)
# E = 0.02002255985047241 (Model 0)
# Estd = 0.029339817110615472 (Model 0)
# F = 0.15537570621436883 (Model 0)
# Fstd = 0.030007597529008185 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.02002255985047241
# Estd = 0.029339817110615472
# Fmax = 0.15537570621436883
# Fstd = 0.030007597529008185
#
# Step 43: Model not trained.
#
#
# ============================ Step: 44 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3909459114074707 s)
# Predict energy_uncertainty (0.3691706657409668 s)
# Predict forces (1.3685579299926758 s)
# Predict forces_uncertainty (1.7241384983062744 s)
# E = 0.022192229196476898 (Model 0)
# Estd = 0.029639877918508764 (Model 0)
# F = 0.16106232566263837 (Model 0)
# Fstd = 0.0325386818288311 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.022192229196476898
# Estd = 0.029639877918508764
# Fmax = 0.16106232566263837
# Fstd = 0.0325386818288311
#
# Step 44: Model not trained.
#
#
# ============================ Step: 45 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3775906562805176 s)
# Predict energy_uncertainty (0.40960049629211426 s)
# Predict forces (1.375239372253418 s)
# Predict forces_uncertainty (1.673466444015503 s)
# E = 0.0244543846941927 (Model 0)
# Estd = 0.02997102923033024 (Model 0)
# F = 0.1672680258445185 (Model 0)
# Fstd = 0.03521168431858944 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.0244543846941927
# Estd = 0.02997102923033024
# Fmax = 0.1672680258445185
# Fstd = 0.03521168431858944
#
# Step 45: Model not trained.
#
#
# ============================ Step: 46 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3832542896270752 s)
# Predict energy_uncertainty (0.3672506809234619 s)
# Predict forces (1.2778127193450928 s)
# Predict forces_uncertainty (1.5299267768859863 s)
# E = 0.026769798433723846 (Model 0)
# Estd = 0.030323225790024992 (Model 0)
# F = 0.17348237209387488 (Model 0)
# Fstd = 0.03790324192417447 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.026769798433723846
# Estd = 0.030323225790024992
# Fmax = 0.17348237209387488
# Fstd = 0.03790324192417447
#
# Step 46: Model not trained.
#
#
# ============================ Step: 47 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.4038875102996826 s)
# Predict energy_uncertainty (0.34802985191345215 s)
# Predict forces (1.1542234420776367 s)
# Predict forces_uncertainty (1.7501919269561768 s)
# E = 0.029141717340828155 (Model 0)
# Estd = 0.030700731691061273 (Model 0)
# F = 0.17946428837188758 (Model 0)
# Fstd = 0.040617010213798134 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.029141717340828155
# Estd = 0.030700731691061273
# Fmax = 0.17946428837188758
# Fstd = 0.040617010213798134
#
# Step 47: Model not trained.
#
#
# ============================ Step: 48 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3733203411102295 s)
# Predict energy_uncertainty (0.33779096603393555 s)
# Predict forces (1.254448652267456 s)
# Predict forces_uncertainty (1.5213382244110107 s)
# E = 0.03157661597164796 (Model 0)
# Estd = 0.031103156862470956 (Model 0)
# F = 0.18508260125223888 (Model 0)
# Fstd = 0.04332373744821134 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.03157661597164796
# Estd = 0.031103156862470956
# Fmax = 0.18508260125223888
# Fstd = 0.04332373744821134
#
# Step 48: Model not trained.
#
#
# ============================ Step: 49 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.36615920066833496 s)
# Predict energy_uncertainty (0.36311769485473633 s)
# Predict forces (1.2570703029632568 s)
# Predict forces_uncertainty (1.6626622676849365 s)
# E = 0.03402649572190275 (Model 0)
# Estd = 0.03151835199924247 (Model 0)
# F = 0.19019778226541073 (Model 0)
# Fstd = 0.046015170861569574 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.03402649572190275
# Estd = 0.03151835199924247
# Fmax = 0.19019778226541073
# Fstd = 0.046015170861569574
#
# Step 49: Model not trained.
#
#
# ============================ Step: 50 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3859426975250244 s)
# Predict energy_uncertainty (0.37999796867370605 s)
# Predict forces (1.4568476676940918 s)
# Predict forces_uncertainty (1.804391860961914 s)
# E = 0.036455255517577 (Model 0)
# Estd = 0.03194129050378802 (Model 0)
# F = 0.1953470656515817 (Model 0)
# Fstd = 0.04858246086382661 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.036455255517577
# Estd = 0.03194129050378802
# Fmax = 0.1953470656515817
# Fstd = 0.04858246086382661
#
# Step 50: Model not trained.
#
#
# ============================ Step: 51 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.39708614349365234 s)
# Predict energy_uncertainty (0.36411404609680176 s)
# Predict forces (1.3396718502044678 s)
# Predict forces_uncertainty (1.6641061305999756 s)
# E = 0.03891498023109263 (Model 0)
# Estd = 0.032384777397709924 (Model 0)
# F = 0.2001619343769172 (Model 0)
# Fstd = 0.05122734102008507 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.03891498023109263
# Estd = 0.032384777397709924
# Fmax = 0.2001619343769172
# Fstd = 0.05122734102008507
#
# Step 51: Model not trained.
#
#
# ============================ Step: 52 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.37143802642822266 s)
# Predict energy_uncertainty (0.3655416965484619 s)
# Predict forces (1.314396858215332 s)
# Predict forces_uncertainty (1.7265846729278564 s)
# E = 0.04143012588573969 (Model 0)
# Estd = 0.032849535009569705 (Model 0)
# F = 0.2052190205911179 (Model 0)
# Fstd = 0.05398386557840711 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.04143012588573969
# Estd = 0.032849535009569705
# Fmax = 0.2052190205911179
# Fstd = 0.05398386557840711
#
# Step 52: Model not trained.
#
#
# ============================ Step: 53 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.41544079780578613 s)
# Predict energy_uncertainty (0.33664941787719727 s)
# Predict forces (1.272444486618042 s)
# Predict forces_uncertainty (0.9751937389373779 s)
# E = 0.044042233286210486 (Model 0)
# Estd = 0.03334817310578177 (Model 0)
# F = 0.21006022778351532 (Model 0)
# Fstd = 0.0567711168076748 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.044042233286210486
# Estd = 0.03334817310578177
# Fmax = 0.21006022778351532
# Fstd = 0.0567711168076748
#
# Step 53: Model not trained.
#
#
# ============================ Step: 54 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.09980440139770508 s)
# Predict energy_uncertainty (0.09245061874389648 s)
# Predict forces (0.448810338973999 s)
# Predict forces_uncertainty (0.5227017402648926 s)
# E = 0.04671358517570634 (Model 0)
# Estd = 0.033865333744633956 (Model 0)
# F = 0.21514639453966752 (Model 0)
# Fstd = 0.05948328863372541 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.04671358517570634
# Estd = 0.033865333744633956
# Fmax = 0.21514639453966752
# Fstd = 0.05948328863372541
#
# Step 54: Model not trained.
#
#
# ============================ Step: 55 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.18139910697937012 s)
# Predict energy_uncertainty (0.24946999549865723 s)
# Predict forces (0.7210006713867188 s)
# Predict forces_uncertainty (0.5482385158538818 s)
# E = 0.04946263242419413 (Model 0)
# Estd = 0.03440860268346456 (Model 0)
# F = 0.2204785408934741 (Model 0)
# Fstd = 0.062241249457455725 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.04946263242419413
# Estd = 0.03440860268346456
# Fmax = 0.2204785408934741
# Fstd = 0.062241249457455725
#
# Step 55: Model not trained.
#
#
# ============================ Step: 56 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.11270427703857422 s)
# Predict energy_uncertainty (0.1003117561340332 s)
# Predict forces (0.45534443855285645 s)
# Predict forces_uncertainty (0.5121808052062988 s)
# E = 0.05225890633146424 (Model 0)
# Estd = 0.03497111976273275 (Model 0)
# F = 0.22582170341612667 (Model 0)
# Fstd = 0.06503212936522443 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.05225890633146424
# Estd = 0.03497111976273275
# Fmax = 0.22582170341612667
# Fstd = 0.06503212936522443
#
# Step 56: Model not trained.
#
#
# ============================ Step: 57 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.09363222122192383 s)
# Predict energy_uncertainty (0.09514117240905762 s)
# Predict forces (0.3794991970062256 s)
# Predict forces_uncertainty (0.46837544441223145 s)
# E = 0.05505010756047879 (Model 0)
# Estd = 0.03553932930343514 (Model 0)
# F = 0.23113089930179642 (Model 0)
# Fstd = 0.06774154502473963 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.05505010756047879
# Estd = 0.03553932930343514
# Fmax = 0.23113089930179642
# Fstd = 0.06774154502473963
#
# Step 57: Model not trained.
#
#
# ============================ Step: 58 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.12087821960449219 s)
# Predict energy_uncertainty (0.11085772514343262 s)
# Predict forces (1.071838617324829 s)
# Predict forces_uncertainty (1.6651031970977783 s)
# E = 0.057881264209865835 (Model 0)
# Estd = 0.03612868349322419 (Model 0)
# F = 0.23645924986770084 (Model 0)
# Fstd = 0.07034936311383926 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.057881264209865835
# Estd = 0.03612868349322419
# Fmax = 0.23645924986770084
# Fstd = 0.07034936311383926
#
# Step 58: Model not trained.
#
#
# ============================ Step: 59 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3935861587524414 s)
# Predict energy_uncertainty (0.36571645736694336 s)
# Predict forces (1.2516849040985107 s)
# Predict forces_uncertainty (1.6193087100982666 s)
# E = 0.060772004005133606 (Model 0)
# Estd = 0.03674465080653092 (Model 0)
# F = 0.24170229670540885 (Model 0)
# Fstd = 0.07297911163379667 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.060772004005133606
# Estd = 0.03674465080653092
# Fmax = 0.24170229670540885
# Fstd = 0.07297911163379667
#
# Step 59: Model not trained.
#
#
# ============================ Step: 60 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3792612552642822 s)
# Predict energy_uncertainty (0.3664267063140869 s)
# Predict forces (1.3289921283721924 s)
# Predict forces_uncertainty (1.6025254726409912 s)
# E = 0.06361280561078875 (Model 0)
# Estd = 0.03735707383060223 (Model 0)
# F = 0.24680276431889683 (Model 0)
# Fstd = 0.07555763408118646 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.06361280561078875
# Estd = 0.03735707383060223
# Fmax = 0.24680276431889683
# Fstd = 0.07555763408118646
#
# Step 60: Model not trained.
#
#
# ============================ Step: 61 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.38333749771118164 s)
# Predict energy_uncertainty (0.3365299701690674 s)
# Predict forces (1.284132957458496 s)
# Predict forces_uncertainty (1.7025916576385498 s)
# E = 0.0664476729930803 (Model 0)
# Estd = 0.0379693926463993 (Model 0)
# F = 0.25175480546008966 (Model 0)
# Fstd = 0.07805362929328603 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.0664476729930803
# Estd = 0.0379693926463993
# Fmax = 0.25175480546008966
# Fstd = 0.07805362929328603
#
# Step 61: Model not trained.
#
#
# ============================ Step: 62 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.39777112007141113 s)
# Predict energy_uncertainty (0.34006428718566895 s)
# Predict forces (1.4333999156951904 s)
# Predict forces_uncertainty (1.6839721202850342 s)
# E = 0.06928006478422288 (Model 0)
# Estd = 0.03858626613338892 (Model 0)
# F = 0.2566090919736405 (Model 0)
# Fstd = 0.0804148034092231 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.06928006478422288
# Estd = 0.03858626613338892
# Fmax = 0.2566090919736405
# Fstd = 0.0804148034092231
#
# Step 62: Model not trained.
#
#
# ============================ Step: 63 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.448836088180542 s)
# Predict energy_uncertainty (0.4286623001098633 s)
# Predict forces (1.4012465476989746 s)
# Predict forces_uncertainty (1.7627205848693848 s)
# E = 0.07209821277846673 (Model 0)
# Estd = 0.03920352316006234 (Model 0)
# F = 0.2616912427858678 (Model 0)
# Fstd = 0.08264561212152227 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.07209821277846673
# Estd = 0.03920352316006234
# Fmax = 0.2616912427858678
# Fstd = 0.08264561212152227
#
# Step 63: Model not trained.
#
#
# ============================ Step: 64 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.46924638748168945 s)
# Predict energy_uncertainty (0.43004798889160156 s)
# Predict forces (1.4323954582214355 s)
# Predict forces_uncertainty (1.4620299339294434 s)
# E = 0.07493699115671548 (Model 0)
# Estd = 0.03983617737872687 (Model 0)
# F = 0.26664229346508733 (Model 0)
# Fstd = 0.08479448544521827 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.07493699115671548
# Estd = 0.03983617737872687
# Fmax = 0.26664229346508733
# Fstd = 0.08479448544521827
#
# Step 64: Model not trained.
#
#
# ============================ Step: 65 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.35484957695007324 s)
# Predict energy_uncertainty (0.45934462547302246 s)
# Predict forces (1.2194404602050781 s)
# Predict forces_uncertainty (1.6530697345733643 s)
# E = 0.0777526805971438 (Model 0)
# Estd = 0.04047006860727068 (Model 0)
# F = 0.2711978134252202 (Model 0)
# Fstd = 0.08688642802930628 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.0777526805971438
# Estd = 0.04047006860727068
# Fmax = 0.2711978134252202
# Fstd = 0.08688642802930628
#
# Step 65: Model not trained.
#
#
# ============================ Step: 66 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.39305830001831055 s)
# Predict energy_uncertainty (0.3847317695617676 s)
# Predict forces (1.3690118789672852 s)
# Predict forces_uncertainty (1.685218334197998 s)
# E = 0.0805404574019013 (Model 0)
# Estd = 0.0410963715492421 (Model 0)
# F = 0.2755024495750528 (Model 0)
# Fstd = 0.08882778460584899 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.0805404574019013
# Estd = 0.0410963715492421
# Fmax = 0.2755024495750528
# ...
# Estd = 0.04650412776445243
# Fmax = 0.3136383314489415
# Fstd = 0.10248449581908867
#
# Step 75: Model not trained.
#
#
# ============================ Step: 76 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.38341808319091797 s)
# Predict energy_uncertainty (0.3513224124908447 s)
# Predict forces (1.325354814529419 s)
# Predict forces_uncertainty (1.6733903884887695 s)
# E = 0.10736307357055697 (Model 0)
# Estd = 0.04705229045253705 (Model 0)
# F = 0.31847103361466106 (Model 0)
# Fstd = 0.10348274207675429 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.10736307357055697
# Estd = 0.04705229045253705
# Fmax = 0.31847103361466106
# Fstd = 0.10348274207675429
#
# Step 76: Model not trained.
#
#
# ============================ Step: 77 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3806345462799072 s)
# Predict energy_uncertainty (0.3514237403869629 s)
# Predict forces (1.3040058612823486 s)
# Predict forces_uncertainty (1.694352626800537 s)
# E = 0.10992197261293313 (Model 0)
# Estd = 0.04758957635154279 (Model 0)
# F = 0.3234844011280525 (Model 0)
# Fstd = 0.10443481437703417 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.10992197261293313
# Estd = 0.04758957635154279
# Fmax = 0.3234844011280525
# Fstd = 0.10443481437703417
#
# Step 77: Model not trained.
#
#
# ============================ Step: 78 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3838212490081787 s)
# Predict energy_uncertainty (0.3828310966491699 s)
# Predict forces (1.311335563659668 s)
# Predict forces_uncertainty (1.639092206954956 s)
# E = 0.11246492078999104 (Model 0)
# Estd = 0.048119973826536835 (Model 0)
# F = 0.3280913482222627 (Model 0)
# Fstd = 0.10534614000319005 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.11246492078999104
# Estd = 0.048119973826536835
# Fmax = 0.3280913482222627
# Fstd = 0.10534614000319005
#
# Step 78: Model not trained.
#
#
# ============================ Step: 79 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3993997573852539 s)
# Predict energy_uncertainty (0.3853886127471924 s)
# Predict forces (1.309528112411499 s)
# Predict forces_uncertainty (1.6279983520507812 s)
# E = 0.11508074907920962 (Model 0)
# Estd = 0.04866799659409223 (Model 0)
# F = 0.33266778546857173 (Model 0)
# Fstd = 0.1061251421906586 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.11508074907920962
# Estd = 0.04866799659409223
# Fmax = 0.33266778546857173
# Fstd = 0.1061251421906586
#
# Step 79: Model not trained.
#
#
# ============================ Step: 80 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3832223415374756 s)
# Predict energy_uncertainty (0.3418116569519043 s)
# Predict forces (1.3584227561950684 s)
# Predict forces_uncertainty (1.7599477767944336 s)
# E = 0.11770061274611576 (Model 0)
# Estd = 0.049211296267672545 (Model 0)
# F = 0.33693302003763365 (Model 0)
# Fstd = 0.10688072416070718 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.11770061274611576
# Estd = 0.049211296267672545
# Fmax = 0.33693302003763365
# Fstd = 0.10688072416070718
#
# Step 80: Model not trained.
#
#
# ============================ Step: 81 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.3841547966003418 s)
# Predict energy_uncertainty (0.41421055793762207 s)
# Predict forces (1.3301515579223633 s)
# Predict forces_uncertainty (1.500915288925171 s)
# E = 0.12028341274936238 (Model 0)
# Estd = 0.04974282926318857 (Model 0)
# F = 0.3414034170283469 (Model 0)
# Fstd = 0.10751775846524239 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.12028341274936238
# Estd = 0.04974282926318857
# Fmax = 0.3414034170283469
# Fstd = 0.10751775846524239
#
# Step 81: Model not trained.
#
#
# ============================ Step: 82 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.22295475006103516 s)
# Predict energy_uncertainty (0.21535563468933105 s)
# Predict forces (0.7849421501159668 s)
# Predict forces_uncertainty (1.6318786144256592 s)
# E = 0.12286652944404186 (Model 0)
# Estd = 0.05026778611459028 (Model 0)
# F = 0.3459518928440632 (Model 0)
# Fstd = 0.10813165619479302 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.12286652944404186
# Estd = 0.05026778611459028
# Fmax = 0.3459518928440632
# Fstd = 0.10813165619479302
#
# Step 82: Model not trained.
#
#
# ============================ Step: 83 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (1.1277916431427002 s)
# Predict energy_uncertainty (0.47646164894104004 s)
# Predict forces (1.7162425518035889 s)
# Predict forces_uncertainty (2.67167329788208 s)
# E = 0.1254228569949074 (Model 0)
# Estd = 0.05077902185756466 (Model 0)
# F = 0.35010919391165285 (Model 0)
# Fstd = 0.10859470152523082 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.1254228569949074
# Estd = 0.05077902185756466
# Fmax = 0.35010919391165285
# Fstd = 0.10859470152523082
#
# Step 83: Model not trained.
#
#
# ============================ Step: 84 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.6447393894195557 s)
# Predict energy_uncertainty (0.6733942031860352 s)
# Predict forces (2.4296042919158936 s)
# Predict forces_uncertainty (2.560889959335327 s)
# E = 0.1278734811651634 (Model 0)
# Estd = 0.05125859775275908 (Model 0)
# F = 0.35384080798513967 (Model 0)
# Fstd = 0.10888790669486637 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.1278734811651634
# Estd = 0.05125859775275908
# Fmax = 0.35384080798513967
# Fstd = 0.10888790669486637
#
# Step 84: Model not trained.
#
#
# ============================ Step: 85 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.8396048545837402 s)
# Predict energy_uncertainty (0.5260438919067383 s)
# Predict forces (1.6278209686279297 s)
# Predict forces_uncertainty (2.1193313598632812 s)
# E = 0.13023339315294313 (Model 0)
# Estd = 0.05170535890261037 (Model 0)
# F = 0.3573252150149668 (Model 0)
# Fstd = 0.10907561158013865 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.13023339315294313
# Estd = 0.05170535890261037
# Fmax = 0.3573252150149668
# Fstd = 0.10907561158013865
#
# Step 85: Model not trained.
#
#
# ============================ Step: 86 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.7109520435333252 s)
# Predict energy_uncertainty (0.7310304641723633 s)
# Predict forces (1.884244680404663 s)
# Predict forces_uncertainty (2.9072659015655518 s)
# E = 0.13251803884565327 (Model 0)
# Estd = 0.05211699311048813 (Model 0)
# F = 0.3605361726199134 (Model 0)
# Fstd = 0.10914274505630507 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.13251803884565327
# Estd = 0.05211699311048813
# Fmax = 0.3605361726199134
# Fstd = 0.10914274505630507
#
# Step 86: Model not trained.
#
#
# ============================ Step: 87 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.6684696674346924 s)
# Predict energy_uncertainty (0.6978445053100586 s)
# Predict forces (2.07205867767334 s)
# Predict forces_uncertainty (1.96942138671875 s)
# E = 0.13481742659049045 (Model 0)
# Estd = 0.052531875624884726 (Model 0)
# F = 0.36339460428374076 (Model 0)
# Fstd = 0.10916793949582028 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.13481742659049045
# Estd = 0.052531875624884726
# Fmax = 0.36339460428374076
# Fstd = 0.10916793949582028
#
# Step 87: Model not trained.
#
#
# ============================ Step: 88 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.7187166213989258 s)
# Predict energy_uncertainty (0.6086115837097168 s)
# Predict forces (1.9625332355499268 s)
# Predict forces_uncertainty (2.6678030490875244 s)
# E = 0.13712238388905473 (Model 0)
# Estd = 0.052936049109125374 (Model 0)
# F = 0.36656962739403903 (Model 0)
# Fstd = 0.10919526090759016 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.13712238388905473
# Estd = 0.052936049109125374
# Fmax = 0.36656962739403903
# Fstd = 0.10919526090759016
#
# Step 88: Model not trained.
#
#
# ============================ Step: 89 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.7472326755523682 s)
# Predict energy_uncertainty (0.7360305786132812 s)
# Predict forces (2.1541953086853027 s)
# Predict forces_uncertainty (2.9447598457336426 s)
# E = 0.13937366620459457 (Model 0)
# Estd = 0.05331688843524512 (Model 0)
# F = 0.36947942300476144 (Model 0)
# Fstd = 0.10956785624401087 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.13937366620459457
# Estd = 0.05331688843524512
# Fmax = 0.36947942300476144
# Fstd = 0.10956785624401087
#
# Step 89: Model not trained.
#
#
# ============================ Step: 90 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.5148031711578369 s)
# Predict energy_uncertainty (0.3504796028137207 s)
# Predict forces (1.8362929821014404 s)
# Predict forces_uncertainty (2.803863048553467 s)
# E = 0.14149332576680695 (Model 0)
# Estd = 0.053657027805254776 (Model 0)
# F = 0.37172467193544195 (Model 0)
# Fstd = 0.1115072466181253 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.14149332576680695
# Estd = 0.053657027805254776
# Fmax = 0.37172467193544195
# Fstd = 0.1115072466181253
#
# Step 90: Model not trained.
#
#
# ============================ Step: 91 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.5851233005523682 s)
# Predict energy_uncertainty (0.41698765754699707 s)
# Predict forces (1.7583034038543701 s)
# Predict forces_uncertainty (2.203915596008301 s)
# E = 0.14354180475614853 (Model 0)
# Estd = 0.05397381938097072 (Model 0)
# F = 0.37340276857161914 (Model 0)
# Fstd = 0.11338899267420395 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.14354180475614853
# Estd = 0.05397381938097072
# Fmax = 0.37340276857161914
# Fstd = 0.11338899267420395
#
# Step 91: Model not trained.
#
#
# ============================ Step: 92 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.6030318737030029 s)
# Predict energy_uncertainty (0.7170376777648926 s)
# Predict forces (2.1568987369537354 s)
# Predict forces_uncertainty (3.054572343826294 s)
# E = 0.14559673168047305 (Model 0)
# Estd = 0.05427461651262047 (Model 0)
# F = 0.3750612488877648 (Model 0)
# Fstd = 0.11517923987032952 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.14559673168047305
# Estd = 0.05427461651262047
# Fmax = 0.3750612488877648
# Fstd = 0.11517923987032952
#
# Step 92: Model not trained.
#
#
# ============================ Step: 93 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.7470064163208008 s)
# Predict energy_uncertainty (0.8233668804168701 s)
# Predict forces (2.002988815307617 s)
# Predict forces_uncertainty (2.4143292903900146 s)
# E = 0.14763368058632342 (Model 0)
# Estd = 0.05455255551561391 (Model 0)
# F = 0.3761606252534399 (Model 0)
# Fstd = 0.11686777772850271 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.14763368058632342
# Estd = 0.05455255551561391
# Fmax = 0.3761606252534399
# Fstd = 0.11686777772850271
#
# Step 93: Model not trained.
#
#
# ============================ Step: 94 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.7963101863861084 s)
# Predict energy_uncertainty (0.9016447067260742 s)
# Predict forces (2.905893087387085 s)
# Predict forces_uncertainty (2.6718664169311523 s)
# E = 0.149668961110756 (Model 0)
# Estd = 0.054815759078419464 (Model 0)
# F = 0.3770526982513054 (Model 0)
# Fstd = 0.11837326946376306 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.149668961110756
# Estd = 0.054815759078419464
# Fmax = 0.3770526982513054
# Fstd = 0.11837326946376306
#
# Step 94: Model not trained.
#
#
# ============================ Step: 95 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.683466911315918 s)
# Predict energy_uncertainty (0.43259358406066895 s)
# Predict forces (3.1907541751861572 s)
# Predict forces_uncertainty (3.128100872039795 s)
# E = 0.15162481093380864 (Model 0)
# Estd = 0.055032621836223615 (Model 0)
# F = 0.37778375016366533 (Model 0)
# Fstd = 0.11955249784479673 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.15162481093380864
# Estd = 0.055032621836223615
# Fmax = 0.37778375016366533
# Fstd = 0.11955249784479673
#
# Step 95: Model not trained.
#
#
# ============================ Step: 96 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.6092233657836914 s)
# Predict energy_uncertainty (0.4936668872833252 s)
# Predict forces (1.638136386871338 s)
# Predict forces_uncertainty (3.1239798069000244 s)
# E = 0.1535211034171835 (Model 0)
# Estd = 0.05521546850704592 (Model 0)
# F = 0.3783465299870477 (Model 0)
# Fstd = 0.12049117983301803 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.1535211034171835
# Estd = 0.05521546850704592
# Fmax = 0.3783465299870477
# Fstd = 0.12049117983301803
#
# Step 96: Model not trained.
#
#
# ============================ Step: 97 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.5440502166748047 s)
# Predict energy_uncertainty (0.44158220291137695 s)
# Predict forces (2.252169609069824 s)
# Predict forces_uncertainty (2.3699212074279785 s)
# E = 0.15543323250005248 (Model 0)
# Estd = 0.055396970649259004 (Model 0)
# F = 0.3786171684664092 (Model 0)
# Fstd = 0.12127903505877893 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.15543323250005248
# Estd = 0.055396970649259004
# Fmax = 0.3786171684664092
# Fstd = 0.12127903505877893
#
# Step 97: Model not trained.
#
#
# ============================ Step: 98 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.6357238292694092 s)
# Predict energy_uncertainty (0.41728806495666504 s)
# Predict forces (2.1491405963897705 s)
# Predict forces_uncertainty (2.6621458530426025 s)
# E = 0.15726693423477256 (Model 0)
# Estd = 0.05554501554109754 (Model 0)
# F = 0.38015480017374254 (Model 0)
# Fstd = 0.12189554378034892 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.15726693423477256
# Estd = 0.05554501554109754
# Fmax = 0.38015480017374254
# Fstd = 0.12189554378034892
#
# Step 98: Model not trained.
#
#
# ============================ Step: 99 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (1.011993646621704 s)
# Predict energy_uncertainty (0.44678831100463867 s)
# Predict forces (1.7863478660583496 s)
# Predict forces_uncertainty (2.0222256183624268 s)
# E = 0.15908634465260374 (Model 0)
# Estd = 0.055674412347785064 (Model 0)
# F = 0.3819813082565542 (Model 0)
# Fstd = 0.12226149388660129 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.15908634465260374
# Estd = 0.055674412347785064
# Fmax = 0.3819813082565542
# Fstd = 0.12226149388660129
#
# Step 99: Model not trained.
#
#
# ============================ Step: 100 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.4363219738006592 s)
# Predict energy_uncertainty (0.6738331317901611 s)
# Predict forces (2.0243613719940186 s)
# Predict forces_uncertainty (2.4830856323242188 s)
# E = 0.16087431156631493 (Model 0)
# Estd = 0.05579034958622188 (Model 0)
# F = 0.38371579053091487 (Model 0)
# Fstd = 0.12253971789856286 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.16087431156631493
# Estd = 0.05579034958622188
# Fmax = 0.38371579053091487
# Fstd = 0.12253971789856286
#
# Step 100: Model not trained.
#
#
# ============================ Step: 101 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.7651355266571045 s)
# Predict energy_uncertainty (0.6761763095855713 s)
# Predict forces (2.2270865440368652 s)
# Predict forces_uncertainty (2.980672597885132 s)
# E = 0.1626505697509406 (Model 0)
# Estd = 0.055895591628980626 (Model 0)
# F = 0.3849417517708383 (Model 0)
# Fstd = 0.12271952193154845 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.1626505697509406
# Estd = 0.055895591628980626
# Fmax = 0.3849417517708383
# Fstd = 0.12271952193154845
#
# Step 101: Model not trained.
#
# Simulation complete!
#   Total wall time: 424.4 s
#   Final training structures: 19
#   Final energy: 0.1627 eV

# %% [markdown]
# ## Visualizing What Just Happened
#
# Let's plot the energy trajectory and the training data growth together.

# %%
# ============================================================
# PLOT BASELINE RESULTS
# ============================================================
n_steps_ran = len(n_training_at_step)
fig, axes = plt.subplots(2, 1, figsize=(12, 8), sharex=True)

# Energy
axes[0].plot(energies, 'r-', alpha=0.6, linewidth=0.5)
axes[0].set_ylabel('Energy (eV)', fontsize=12)
axes[0].set_title(f'FALCON OTF-MD: Pt, T={T} K, ε={accuracy_e} eV, '
                  f'modelsize={model_size}',
                  fontsize=14)
axes[0].grid(True, alpha=0.3)

# Training data growth
axes[1].plot(n_training_at_step, 'b-', linewidth=2)
axes[1].set_xlabel('MD step', fontsize=12)
axes[1].set_ylabel('Training structures', fontsize=12)
axes[1].set_title('Growth of training data', fontsize=14)
axes[1].grid(True, alpha=0.3)

# Mark where the training set stops growing.
# Look at the last 20% of the run and find the first step from which
# the count never changes again.
tail_start = int(0.8 * n_steps_ran)
final_count = n_training_at_step[-1]
plateau_start = None
for i in range(tail_start, n_steps_ran):
    if n_training_at_step[i] == final_count:
        # Walk backwards to find the earliest index with this value.
        j = i
        while j > 0 and n_training_at_step[j - 1] == final_count:
            j -= 1
        plateau_start = j
        break

if plateau_start is not None and plateau_start < n_steps_ran - 1:
    axes[1].axvline(x=plateau_start, color='green', linestyle='--',
                    alpha=0.7, label=f'Plateau at step {plateau_start}')
    axes[1].legend()

plt.tight_layout()
plt.savefig('outputs/falcon_baseline.png', dpi=150)
plt.show()

# ============================================================
# QUANTIFY THE TRAINING PHASES
# ============================================================
# Divide the run into thirds, regardless of how many steps we ran.
i1 = n_steps_ran // 3
i2 = 2 * n_steps_ran // 3

n_early = n_training_at_step[i1] - n_training_at_step[0]
n_mid   = n_training_at_step[i2] - n_training_at_step[i1]
n_late  = n_training_at_step[-1] - n_training_at_step[i2]

print(f"Training phases (run length: {n_steps_ran} MD steps):")
print(f"  Steps     0 - {i1:>5}: +{n_early} structures")
print(f"  Steps {i1:>5} - {i2:>5}: +{n_mid} structures")
print(f"  Steps {i2:>5} - {n_steps_ran:>5}: +{n_late} structures")
# Out:
# Training phases (run length: 100 MD steps):
#   Steps     0 -    33: +8 structures
#   Steps    33 -    66: +0 structures
#   Steps    66 -   100: +0 structures

# %% [markdown]
# ## How Does ε Affect the Simulation?
#
# **Before running, predict:**
# - If ε = 0.20 eV: more or fewer training structures?
# - If ε = 0.05 eV: more or fewer training structures?
# - Is the relationship linear?
#
# Let's test our predictions.

# %%
# ============================================================
# IMPORTS (just in case ;) )
# ============================================================
import os
import time
import numpy as np
import matplotlib.pyplot as plt

from ase import units
from ase.build import bulk
from ase.calculators.emt import EMT
from ase.calculators.singlepoint import SinglePointCalculator
from ase.io import read
from ase.optimize import QuasiNewton
from ase.md.langevin import Langevin

from falcon_md.otf_calculator import FALCON
from falcon_md.models.agox_models import GPR as FalconGPR

# Windows patches
if not hasattr(os, "sched_getaffinity"):
    os.sched_getaffinity = lambda pid: set(range(os.cpu_count() or 1))
os.environ["RAY_raylet_start_wait_time_s"] = "120"

os.makedirs("outputs", exist_ok=True)

# ============================================================
# SWEEP OVER ACCURACY THRESHOLDS
# ============================================================
T = 600
n_steps_short = 100          # shorter for the sweep
thresholds = [0.05, 0.10, 0.15, 0.20]
model_size = 200

results_eps = {}

def generate_training_data(tag):
    """Build a fresh Pt supercell and return a small training set."""
    atoms = bulk('Pt', 'fcc', a=3.92, cubic=True).repeat((3, 3, 3))
    atoms.rattle(0.1)
    atoms.calc = EMT()

    frames = []
    def collect(atoms):
        frame = atoms.copy()
        frame.calc = SinglePointCalculator(
            frame,
            energy=atoms.get_potential_energy(),
            forces=atoms.get_forces(),
        )
        frames.append(frame)

    qn = QuasiNewton(atoms, logfile=f"outputs/opt_{tag}.log")
    qn.attach(collect, interval=1, atoms=atoms)
    qn.run(fmax=0.05, steps=20)

    return atoms, frames

for eps in thresholds:
    print(f"\n{'='*50}")
    print(f"Running ε = {eps} eV")
    print(f"{'='*50}")

    atoms, training_data = generate_training_data(f"eps{eps}")
    print(f"  Initial training data: {len(training_data)} structures")

    exact_calc = EMT()
    atoms.calc = FALCON(
        model=FalconGPR(atoms),
        calc=exact_calc,
        training_data=training_data,
        accuracy_e=eps,
        modelsize=model_size,
        train_log=False,        # suppress per-step printout
    )

    t_start = time.time()
    dyn = Langevin(atoms, 1 * units.fs, temperature_K=T, friction=0.002)
    for step in range(n_steps_short):
        dyn.run(1)
    t_total = time.time() - t_start

    n_train = len(atoms.calc.training_data)
    results_eps[eps] = {
        'n_train': n_train,
        'time': t_total,
        'n_steps': n_steps_short,
    }

    print(f"  Training structures: {n_train}")
    print(f"  Total time: {t_total:.1f} s")

# ============================================================
# PLOT RESULTS
# ============================================================
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

eps_vals = list(results_eps.keys())
n_trains = [results_eps[e]['n_train'] for e in eps_vals]
times    = [results_eps[e]['time']    for e in eps_vals]

axes[0].plot(eps_vals, n_trains, 'o-', color='steelblue',
             linewidth=2, markersize=10)
axes[0].set_xlabel('Accuracy threshold ε (eV)', fontsize=12)
axes[0].set_ylabel('Training structures', fontsize=12)
axes[0].set_title('How ε affects DFT calls', fontsize=14)
axes[0].grid(True, alpha=0.3)
axes[0].invert_xaxis()   # lower ε on the right

axes[1].plot(eps_vals, times, 's-', color='coral',
             linewidth=2, markersize=10)
axes[1].set_xlabel('Accuracy threshold ε (eV)', fontsize=12)
axes[1].set_ylabel('Total wall time (s)', fontsize=12)
axes[1].set_title('How ε affects simulation time', fontsize=14)
axes[1].grid(True, alpha=0.3)
axes[1].invert_xaxis()

plt.tight_layout()
plt.savefig('outputs/eps_sweep.png', dpi=150)
plt.show()

print("\nSummary:")
for eps in eps_vals:
    print(f"  ε = {eps:.2f} eV → {results_eps[eps]['n_train']} structures, "
          f"{results_eps[eps]['time']:.1f} s")
# Out:
# ==================================================
# Running ε = 0.05 eV
# ==================================================
#   Initial training data: 9 structures
#
# You are using the Gaussian Process Regression model implemented in AGOX. If you use this model in a publication, please cite:
# Mads-Peter V. Christiansen, Nikolaj Rønne, Bjørk Hammer, "Atomistic Global Optimization X: A Python package for optimization of atomistic structures", J. Chem. Phys. 157, 054701 (2022),
# <https://arxiv.org/abs/2204.01451>
#
# If you are using FALCON in a publication, please cite:
#  Felis, N., Dononelli, W. (2025). FALCON: fast active learning for machine learning potentials in atomistic and ab initio molecular dynamics simulations. npj Comput. Mater., https://doi.org/10.1038/s41524-025-01897-8
#
# ============================ Step: 1 ============================
#
# Total structures in training data: 9
# 1 active Models.
# (9, 1, 60)
# [0 0 0 0 0 0 0 0 0]
# Cluster 0 contains 9 objects.
# Clustering of 9 took 6.353742837905884 s.
# <class 'agox.models.GPR.GPR.GPR'>
# C:\Users\carli\AppData\Local\miniconda\envs\ci\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Updating attributes: ['X', 'Y']
# Updated 2 attributes on Ray Actors in 0.05 s.
# Updating attributes: ['alpha', 'K_inv', 'kernel', 'K', 'mean_energy',
# '_ready_state']
# Updated 6 attributes on Ray Actors in 0.06 s.
# ------ Model Info ------
# Descriptor:
#     Fingerprint
# Kernel:
#     12.3**2 * 0.1**2 * RBF(length_scale=0.205) + 0.995**2 *
# RBF(length_scale=0.94) + Noise(noise_level=0.01)
# Filter:
#     EnergyFilter removed 0 structures
#     - Data before filter: 9
#     - Data after filter: 9
# ------ Training Info ------
# Training data size: 9
# Neg. log marginal likelihood.: 6.29
# Hyperparameter optimizations: 12
# Model 0 trained with 9 structures (8.929936170578003 s).
#
# Model trained with initial training data. (8.929936170578003 s)
#
# Model 0...
# Predict energy (0.6265144348144531 s)
# Predict energy_uncertainty (1.4046199321746826 s)
# Predict forces (6.6881420612335205 s)
# Predict forces_uncertainty (7.497789144515991 s)
# E = -0.02011260685376559 (Model 0)
# Estd = 0.052926234224986074 (Model 0)
# F = 0.03132366532898964 (Model 0)
# Fstd = 0.006609650916969936 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.02011260685376559
# Estd = 0.052926234224986074
# Fmax = 0.03132366532898964
# Fstd = 0.006609650916969936
#
# Exact calculation...
# Exact Calculation (0.12804532051086426 s)
# Real energy = -0.011832348427130768
# Real Fmax = 0.031187058244219686
# New structure is added to Model 0.
#
# Step 1: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 2 ============================
#
# Total structures in training data: 10
# Model 0...
# Predict energy (1.0860545635223389 s)
# Predict energy_uncertainty (0.5587313175201416 s)
# Predict forces (6.273449420928955 s)
# Predict forces_uncertainty (5.221712112426758 s)
# E = -0.020114551702258066 (Model 0)
# Estd = 0.05292605126938433 (Model 0)
# F = 0.031246637233721498 (Model 0)
# Fstd = 0.006595281141904051 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.020114551702258066
# Estd = 0.05292605126938433
# Fmax = 0.031246637233721498
# Fstd = 0.006595281141904051
#
# Exact calculation...
# Exact Calculation (0.19087457656860352 s)
# Real energy = -0.011834447595376218
# Real Fmax = 0.031096178553890762
# New structure is added to Model 0.
#
# Step 2: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 3 ============================
#
# Total structures in training data: 11
# Model 0...
# Predict energy (0.6532857418060303 s)
# Predict energy_uncertainty (0.79695725440979 s)
# Predict forces (5.272900819778442 s)
# Predict forces_uncertainty (3.0390350818634033 s)
# E = -0.020114199121174625 (Model 0)
# Estd = 0.052925659986236204 (Model 0)
# F = 0.031200482132525097 (Model 0)
# Fstd = 0.006578107559790776 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.020114199121174625
# Estd = 0.052925659986236204
# Fmax = 0.031200482132525097
# Fstd = 0.006578107559790776
#
# Exact calculation...
# Exact Calculation (0.14286184310913086 s)
# Real energy = -0.01183408646173234
# Real Fmax = 0.031043672900589906
# New structure is added to Model 0.
#
# Step 3: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 4 ============================
#
# Total structures in training data: 12
# Model 0...
# Predict energy (0.6529402732849121 s)
# Predict energy_uncertainty (0.651289701461792 s)
# Predict forces (1.9714014530181885 s)
# Predict forces_uncertainty (2.7668814659118652 s)
# E = -0.020105051472163016 (Model 0)
# Estd = 0.05292488512340289 (Model 0)
# F = 0.03095084037278185 (Model 0)
# Fstd = 0.0065647185112935845 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.020105051472163016
# Estd = 0.05292488512340289
# Fmax = 0.03095084037278185
# Fstd = 0.0065647185112935845
#
# Exact calculation...
# Exact Calculation (0.17560887336730957 s)
# Real energy = -0.01182448670458669
# Real Fmax = 0.030765889182769936
# New structure is added to Model 0.
#
# Step 4: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 5 ============================
#
# Total structures in training data: 13
# Model 0...
# Predict energy (0.7000477313995361 s)
# Predict energy_uncertainty (0.7316620349884033 s)
# Predict forces (2.241137742996216 s)
# Predict forces_uncertainty (2.7978479862213135 s)
# E = -0.020083288491183016 (Model 0)
# Estd = 0.052923952418985995 (Model 0)
# F = 0.030902158036890323 (Model 0)
# Fstd = 0.006562176696067005 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.020083288491183016
# Estd = 0.052923952418985995
# Fmax = 0.030902158036890323
# Fstd = 0.006562176696067005
#
# Exact calculation...
# Exact Calculation (0.25444889068603516 s)
# Real energy = -0.011802008431647693
# Real Fmax = 0.030671900587532032
# New structure is added to Model 0.
#
# Step 5: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 6 ============================
#
# Total structures in training data: 14
# Model 0...
# Predict energy (0.7783052921295166 s)
# Predict energy_uncertainty (0.7158679962158203 s)
# Predict forces (2.05027437210083 s)
# Predict forces_uncertainty (2.4203875064849854 s)
# E = -0.020045751183815685 (Model 0)
# Estd = 0.052921608521803214 (Model 0)
# F = 0.03130406356539977 (Model 0)
# Fstd = 0.0065449736394370805 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.020045751183815685
# Estd = 0.052921608521803214
# Fmax = 0.03130406356539977
# Fstd = 0.0065449736394370805
#
# Exact calculation...
# Exact Calculation (0.0965111255645752 s)
# Real energy = -0.011763668171450803
# Real Fmax = 0.031016725066195103
# New structure is added to Model 0.
#
# Step 6: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 7 ============================
#
# Total structures in training data: 15
# Model 0...
# Predict energy (0.7300951480865479 s)
# Predict energy_uncertainty (0.9053733348846436 s)
# Predict forces (2.5441999435424805 s)
# Predict forces_uncertainty (3.0381550788879395 s)
# E = -0.019991542483084768 (Model 0)
# Estd = 0.052917646573415314 (Model 0)
# F = 0.03162922654563465 (Model 0)
# Fstd = 0.0065294905967250684 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.019991542483084768
# Estd = 0.052917646573415314
# Fmax = 0.03162922654563465
# Fstd = 0.0065294905967250684
#
# Exact calculation...
# Exact Calculation (0.194091796875 s)
# Real energy = -0.011708356541927145
# Real Fmax = 0.031249618684801004
# New structure is added to Model 0.
#
# Step 7: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 8 ============================
#
# Total structures in training data: 16
# Model 0...
# Predict energy (0.7300634384155273 s)
# Predict energy_uncertainty (1.2668728828430176 s)
# Predict forces (2.0502219200134277 s)
# Predict forces_uncertainty (2.8954927921295166 s)
# E = -0.019925205547868252 (Model 0)
# Estd = 0.05291282276012313 (Model 0)
# F = 0.03195536242669823 (Model 0)
# Fstd = 0.006489537914617463 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.019925205547868252
# Estd = 0.05291282276012313
# Fmax = 0.03195536242669823
# Fstd = 0.006489537914617463
#
# Exact calculation...
# Exact Calculation (0.1618952751159668 s)
# Real energy = -0.011640643333279854
# Real Fmax = 0.03146727664699106
# New structure is added to Model 0.
#
# Step 8: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 9 ============================
#
# Total structures in training data: 17
# Model 0...
# Predict energy (0.8608639240264893 s)
# Predict energy_uncertainty (0.8472630977630615 s)
# Predict forces (2.10554575920105 s)
# Predict forces_uncertainty (2.363769054412842 s)
# E = -0.019844316373718307 (Model 0)
# Estd = 0.05290704339158182 (Model 0)
# F = 0.03229129475782637 (Model 0)
# Fstd = 0.0064526550828672416 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.019844316373718307
# Estd = 0.05290704339158182
# Fmax = 0.03229129475782637
# Fstd = 0.0064526550828672416
#
# Exact calculation...
# Exact Calculation (0.2134685516357422 s)
# Real energy = -0.011557923002879278
# Real Fmax = 0.031703235338925995
# New structure is added to Model 0.
#
# Step 9: New structure added to training data of Model 0. No training is performed since number of new structures for batch training is not reached yet.
#
# ============================ Step: 10 ============================
#
# Total structures in training data: 18
# Model 0...
# Predict energy (0.4332616329193115 s)
# Predict energy_uncertainty (0.49250078201293945 s)
# Predict forces (1.7912285327911377 s)
# Predict forces_uncertainty (2.0459725856781006 s)
# E = -0.01973899073512886 (Model 0)
# Estd = 0.05290019488120231 (Model 0)
# F = 0.032272681581999245 (Model 0)
# Fstd = 0.006442510477439754 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.01973899073512886
# Estd = 0.05290019488120231
# Fmax = 0.032272681581999245
# Fstd = 0.006442510477439754
#
# Exact calculation...
# Exact Calculation (0.10528159141540527 s)
# Real energy = -0.011449631111535297
# Real Fmax = 0.03160430064512832
# New structure is added to Model 0.
# Updating attributes: ['X', 'Y']
# Updated 2 attributes on Ray Actors in 0.11 s.
# Updating attributes: ['alpha', 'K_inv', 'kernel', 'K', 'mean_energy',
# '_ready_state']
# Updated 6 attributes on Ray Actors in 0.13 s.
# ------ Model Info ------
# Descriptor:
#     Fingerprint
# Kernel:
#     13**2 * 0.1**2 * RBF(length_scale=0.216) + 0.995**2 *
# RBF(length_scale=0.976) + Noise(noise_level=0.01)
# Filter:
#     EnergyFilter removed 0 structures
#     - Data before filter: 19
#     - Data after filter: 19
# ------ Training Info ------
# Training data size: 19
# Neg. log marginal likelihood.: -6.78
# Hyperparameter optimizations: 12
# Step 10: Model 0 trained with 19 Structures (15.355743408203125 s). (1 Training steps.)
#
#
# ============================ Step: 11 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.8262274265289307 s)
# Predict energy_uncertainty (0.7463929653167725 s)
# Predict forces (1.9998459815979004 s)
# Predict forces_uncertainty (3.0310416221618652 s)
# E = -0.01363102034833974 (Model 0)
# Estd = 0.02713410118378964 (Model 0)
# F = 0.03268138132775733 (Model 0)
# Fstd = 0.00330159013591812 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.01363102034833974
# Estd = 0.02713410118378964
# Fmax = 0.03268138132775733
# Fstd = 0.00330159013591812
#
# Step 11: Model not trained.
#
#
# ============================ Step: 12 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.7027544975280762 s)
# Predict energy_uncertainty (0.6211869716644287 s)
# Predict forces (2.182671308517456 s)
# Predict forces_uncertainty (2.779087543487549 s)
# E = -0.013467563906566782 (Model 0)
# Estd = 0.027129305375890228 (Model 0)
# F = 0.032853528433849005 (Model 0)
# Fstd = 0.0032998053852852215 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.013467563906566782
# Estd = 0.027129305375890228
# Fmax = 0.032853528433849005
# Fstd = 0.0032998053852852215
#
# Step 12: Model not trained.
#
#
# ============================ Step: 13 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.7666537761688232 s)
# Predict energy_uncertainty (0.7164952754974365 s)
# Predict forces (2.0511109828948975 s)
# Predict forces_uncertainty (2.5000505447387695 s)
# E = -0.013270190651836544 (Model 0)
# Estd = 0.027125115237778042 (Model 0)
# F = 0.03521525507816813 (Model 0)
# Fstd = 0.003348999599843962 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.013270190651836544
# Estd = 0.027125115237778042
# Fmax = 0.03521525507816813
# Fstd = 0.003348999599843962
#
# Step 13: Model not trained.
#
#
# ============================ Step: 14 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.397686243057251 s)
# Predict energy_uncertainty (0.6303184032440186 s)
# Predict forces (1.3396260738372803 s)
# Predict forces_uncertainty (2.681213855743408 s)
# E = -0.013038147437388958 (Model 0)
# Estd = 0.027120668310733814 (Model 0)
# F = 0.03795666619045476 (Model 0)
# Fstd = 0.0033882460698956814 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.013038147437388958
# Estd = 0.027120668310733814
# Fmax = 0.03795666619045476
# Fstd = 0.0033882460698956814
#
# Step 14: Model not trained.
#
#
# ============================ Step: 15 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.460540771484375 s)
# Predict energy_uncertainty (0.41385436058044434 s)
# Predict forces (1.3987987041473389 s)
# Predict forces_uncertainty (2.684758424758911 s)
# E = -0.012767982046803183 (Model 0)
# Estd = 0.0271160102973472 (Model 0)
# F = 0.04052877833136085 (Model 0)
# Fstd = 0.0034252454094043905 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.012767982046803183
# Estd = 0.0271160102973472
# Fmax = 0.04052877833136085
# Fstd = 0.0034252454094043905
#
# Step 15: Model not trained.
#
#
# ============================ Step: 16 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.5229730606079102 s)
# Predict energy_uncertainty (0.4678955078125 s)
# Predict forces (1.7436094284057617 s)
# Predict forces_uncertainty (2.797916889190674 s)
# E = -0.012461288328050268 (Model 0)
# Estd = 0.027111741122972398 (Model 0)
# F = 0.04308613548801073 (Model 0)
# Fstd = 0.0034994126961742484 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.012461288328050268
# Estd = 0.027111741122972398
# Fmax = 0.04308613548801073
# Fstd = 0.0034994126961742484
#
# Step 16: Model not trained.
#
#
# ============================ Step: 17 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.8632028102874756 s)
# Predict energy_uncertainty (0.6746211051940918 s)
# Predict forces (1.7088072299957275 s)
# Predict forces_uncertainty (1.9184741973876953 s)
# E = -0.012118965273005489 (Model 0)
# Estd = 0.02710707337106531 (Model 0)
# F = 0.04596261160718061 (Model 0)
# Fstd = 0.003619363230009547 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.012118965273005489
# Estd = 0.02710707337106531
# Fmax = 0.04596261160718061
# Fstd = 0.003619363230009547
#
# Step 17: Model not trained.
#
#
# ============================ Step: 18 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.7767844200134277 s)
# Predict energy_uncertainty (0.41815924644470215 s)
# Predict forces (1.6423070430755615 s)
# Predict forces_uncertainty (2.250636577606201 s)
# E = -0.011745131713033041 (Model 0)
# Estd = 0.02710269955784805 (Model 0)
# F = 0.04910491980944307 (Model 0)
# Fstd = 0.0037437754263039582 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.011745131713033041
# Estd = 0.02710269955784805
# Fmax = 0.04910491980944307
# Fstd = 0.0037437754263039582
#
# Step 18: Model not trained.
#
#
# ============================ Step: 19 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.6911957263946533 s)
# Predict energy_uncertainty (0.5136103630065918 s)
# Predict forces (1.9085979461669922 s)
# Predict forces_uncertainty (2.2050857543945312 s)
# E = -0.011338822070350196 (Model 0)
# Estd = 0.027098502595080655 (Model 0)
# F = 0.05233807366071311 (Model 0)
# Fstd = 0.0038831438856799672 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.011338822070350196
# Estd = 0.027098502595080655
# Fmax = 0.05233807366071311
# Fstd = 0.0038831438856799672
#
# Step 19: Model not trained.
#
#
# ============================ Step: 20 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.4485321044921875 s)
# Predict energy_uncertainty (0.4230670928955078 s)
# Predict forces (1.5836262702941895 s)
# Predict forces_uncertainty (2.4835586547851562 s)
# E = -0.010893327050397583 (Model 0)
# Estd = 0.027094600234597983 (Model 0)
# F = 0.05563052380376798 (Model 0)
# Fstd = 0.004027109629097345 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.010893327050397583
# Estd = 0.027094600234597983
# Fmax = 0.05563052380376798
# Fstd = 0.004027109629097345
#
# Step 20: Model not trained.
#
#
# ============================ Step: 21 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.7443573474884033 s)
# Predict energy_uncertainty (0.6030902862548828 s)
# Predict forces (1.4920704364776611 s)
# Predict forces_uncertainty (2.052199125289917 s)
# E = -0.010389139664235603 (Model 0)
# Estd = 0.027092169478640845 (Model 0)
# F = 0.05944858166249894 (Model 0)
# Fstd = 0.004182362301666126 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.010389139664235603
# Estd = 0.027092169478640845
# Fmax = 0.05944858166249894
# Fstd = 0.004182362301666126
#
# Step 21: Model not trained.
#
#
# ============================ Step: 22 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.7424404621124268 s)
# Predict energy_uncertainty (0.5416369438171387 s)
# Predict forces (1.9571640491485596 s)
# Predict forces_uncertainty (2.5545763969421387 s)
# E = -0.009841241142382606 (Model 0)
# Estd = 0.02709168714179925 (Model 0)
# F = 0.06445318765691743 (Model 0)
# Fstd = 0.004337847137473346 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.009841241142382606
# Estd = 0.02709168714179925
# Fmax = 0.06445318765691743
# Fstd = 0.004337847137473346
#
# Step 22: Model not trained.
#
#
# ============================ Step: 23 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.5883328914642334 s)
# Predict energy_uncertainty (0.5185132026672363 s)
# Predict forces (1.8521149158477783 s)
# Predict forces_uncertainty (3.2206006050109863 s)
# E = -0.009239883808529359 (Model 0)
# Estd = 0.02709312897211756 (Model 0)
# F = 0.06961215168140666 (Model 0)
# Fstd = 0.004496570860303523 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.009239883808529359
# Estd = 0.02709312897211756
# Fmax = 0.06961215168140666
# Fstd = 0.004496570860303523
#
# Step 23: Model not trained.
#
#
# ============================ Step: 24 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (1.0315062999725342 s)
# Predict energy_uncertainty (0.7161204814910889 s)
# Predict forces (1.7394211292266846 s)
# Predict forces_uncertainty (2.7169179916381836 s)
# E = -0.00859172600679492 (Model 0)
# Estd = 0.02709649301617551 (Model 0)
# F = 0.07423353207144073 (Model 0)
# Fstd = 0.004653710708103071 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.00859172600679492
# Estd = 0.02709649301617551
# Fmax = 0.07423353207144073
# Fstd = 0.004653710708103071
#
# Step 24: Model not trained.
#
#
# ============================ Step: 25 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.5845479965209961 s)
# Predict energy_uncertainty (0.5394296646118164 s)
# Predict forces (2.066169261932373 s)
# Predict forces_uncertainty (1.9972388744354248 s)
# E = -0.007888285048412214 (Model 0)
# Estd = 0.027103812248405225 (Model 0)
# F = 0.07874226386461121 (Model 0)
# Fstd = 0.0049730274893542824 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.007888285048412214
# Estd = 0.027103812248405225
# Fmax = 0.07874226386461121
# Fstd = 0.0049730274893542824
#
# Step 25: Model not trained.
#
#
# ============================ Step: 26 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.46222949028015137 s)
# Predict energy_uncertainty (0.5104169845581055 s)
# Predict forces (1.8502895832061768 s)
# Predict forces_uncertainty (2.641146421432495 s)
# E = -0.007138365401882507 (Model 0)
# Estd = 0.027114700977780428 (Model 0)
# F = 0.08281304128082416 (Model 0)
# Fstd = 0.005462117947257049 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.007138365401882507
# Estd = 0.027114700977780428
# Fmax = 0.08281304128082416
# Fstd = 0.005462117947257049
#
# Step 26: Model not trained.
#
#
# ============================ Step: 27 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.61753249168396 s)
# Predict energy_uncertainty (0.6398453712463379 s)
# Predict forces (2.078568458557129 s)
# Predict forces_uncertainty (2.3399319648742676 s)
# E = -0.006344063038875691 (Model 0)
# Estd = 0.02712871169717903 (Model 0)
# F = 0.08632915700550221 (Model 0)
# Fstd = 0.005978495946440935 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.006344063038875691
# Estd = 0.02712871169717903
# Fmax = 0.08632915700550221
# Fstd = 0.005978495946440935
#
# Step 27: Model not trained.
#
#
# ============================ Step: 28 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.6173686981201172 s)
# Predict energy_uncertainty (0.7488481998443604 s)
# Predict forces (1.8304433822631836 s)
# Predict forces_uncertainty (2.27009654045105 s)
# E = -0.005502078540233213 (Model 0)
# Estd = 0.027148644915360606 (Model 0)
# F = 0.08965676919549154 (Model 0)
# Fstd = 0.006574622871532982 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.005502078540233213
# Estd = 0.027148644915360606
# Fmax = 0.08965676919549154
# Fstd = 0.006574622871532982
#
# Step 28: Model not trained.
#
#
# ============================ Step: 29 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.4753243923187256 s)
# Predict energy_uncertainty (0.5516431331634521 s)
# Predict forces (1.7857611179351807 s)
# Predict forces_uncertainty (2.6594417095184326 s)
# E = -0.0046000252387311535 (Model 0)
# Estd = 0.027174576456022927 (Model 0)
# F = 0.09294772066644955 (Model 0)
# Fstd = 0.007244120866263974 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.0046000252387311535
# Estd = 0.027174576456022927
# Fmax = 0.09294772066644955
# Fstd = 0.007244120866263974
#
# Step 29: Model not trained.
#
#
# ============================ Step: 30 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.8733837604522705 s)
# Predict energy_uncertainty (0.5825991630554199 s)
# Predict forces (1.7283153533935547 s)
# Predict forces_uncertainty (2.368065595626831 s)
# E = -0.0036508824818425323 (Model 0)
# Estd = 0.027205814124305956 (Model 0)
# F = 0.09605604096337621 (Model 0)
# Fstd = 0.007939853524717985 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.0036508824818425323
# Estd = 0.027205814124305956
# Fmax = 0.09605604096337621
# Fstd = 0.007939853524717985
#
# Step 30: Model not trained.
#
#
# ============================ Step: 31 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.5318584442138672 s)
# Predict energy_uncertainty (0.4481620788574219 s)
# Predict forces (1.8260395526885986 s)
# Predict forces_uncertainty (2.4052486419677734 s)
# E = -0.0026769516179102615 (Model 0)
# Estd = 0.02724182279734639 (Model 0)
# F = 0.09899514086551933 (Model 0)
# Fstd = 0.0086559737997885 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.0026769516179102615
# Estd = 0.02724182279734639
# Fmax = 0.09899514086551933
# Fstd = 0.0086559737997885
#
# Step 31: Model not trained.
#
#
# ============================ Step: 32 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.5162980556488037 s)
# Predict energy_uncertainty (0.4851076602935791 s)
# Predict forces (1.809084415435791 s)
# Predict forces_uncertainty (2.6941463947296143 s)
# E = -0.0016686819906502892 (Model 0)
# Estd = 0.02728324710503564 (Model 0)
# F = 0.10188337150423148 (Model 0)
# Fstd = 0.009428559130457809 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.0016686819906502892
# Estd = 0.02728324710503564
# Fmax = 0.10188337150423148
# Fstd = 0.009428559130457809
#
# Step 32: Model not trained.
#
#
# ============================ Step: 33 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.976085901260376 s)
# Predict energy_uncertainty (0.5497910976409912 s)
# Predict forces (1.8186733722686768 s)
# Predict forces_uncertainty (1.4622690677642822 s)
# E = -0.0006135602476913249 (Model 0)
# Estd = 0.02733122550378989 (Model 0)
# F = 0.10494106374636762 (Model 0)
# Fstd = 0.010279961574986798 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = -0.0006135602476913249
# Estd = 0.02733122550378989
# Fmax = 0.10494106374636762
# Fstd = 0.010279961574986798
#
# Step 33: Model not trained.
#
#
# ============================ Step: 34 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.22735977172851562 s)
# Predict energy_uncertainty (0.2654104232788086 s)
# Predict forces (0.8366222381591797 s)
# Predict forces_uncertainty (1.0329351425170898 s)
# E = 0.000458343764796032 (Model 0)
# Estd = 0.027384100616359743 (Model 0)
# F = 0.10808988460602541 (Model 0)
# Fstd = 0.011176631096344425 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.000458343764796032
# Estd = 0.027384100616359743
# Fmax = 0.10808988460602541
# Fstd = 0.011176631096344425
#
# Step 34: Model not trained.
#
#
# ============================ Step: 35 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.23367547988891602 s)
# Predict energy_uncertainty (0.2135930061340332 s)
# Predict forces (1.5341622829437256 s)
# Predict forces_uncertainty (2.845512628555298 s)
# E = 0.0015834457545548242 (Model 0)
# Estd = 0.027442273835184144 (Model 0)
# F = 0.11106553490690839 (Model 0)
# Fstd = 0.012138264512647916 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.0015834457545548242
# Estd = 0.027442273835184144
# Fmax = 0.11106553490690839
# Fstd = 0.012138264512647916
#
# Step 35: Model not trained.
#
#
# ============================ Step: 36 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.6198089122772217 s)
# Predict energy_uncertainty (0.6183667182922363 s)
# Predict forces (3.5180718898773193 s)
# Predict forces_uncertainty (2.4807283878326416 s)
# E = 0.002732364830454692 (Model 0)
# Estd = 0.027505378895763453 (Model 0)
# F = 0.11540518778155796 (Model 0)
# Fstd = 0.013128135696521331 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.002732364830454692
# Estd = 0.027505378895763453
# Fmax = 0.11540518778155796
# Fstd = 0.013128135696521331
#
# Step 36: Model not trained.
#
#
# ============================ Step: 37 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.5263228416442871 s)
# Predict energy_uncertainty (0.46768951416015625 s)
# Predict forces (1.9301023483276367 s)
# Predict forces_uncertainty (2.9251184463500977 s)
# E = 0.00391492370403157 (Model 0)
# Estd = 0.02757496467710655 (Model 0)
# F = 0.11997828687407631 (Model 0)
# Fstd = 0.01409250340458815 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.00391492370403157
# Estd = 0.02757496467710655
# Fmax = 0.11997828687407631
# Fstd = 0.01409250340458815
#
# Step 37: Model not trained.
#
#
# ============================ Step: 38 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.9258792400360107 s)
# Predict energy_uncertainty (0.8236041069030762 s)
# Predict forces (1.9058856964111328 s)
# Predict forces_uncertainty (2.3064587116241455 s)
# E = 0.005121091291806379 (Model 0)
# Estd = 0.02764993084455753 (Model 0)
# F = 0.12404815612480743 (Model 0)
# Fstd = 0.015082732905067625 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.005121091291806379
# Estd = 0.02764993084455753
# Fmax = 0.12404815612480743
# Fstd = 0.015082732905067625
#
# Step 38: Model not trained.
#
#
# ============================ Step: 39 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.670220136642456 s)
# Predict energy_uncertainty (0.7218844890594482 s)
# Predict forces (1.948589563369751 s)
# Predict forces_uncertainty (3.112154006958008 s)
# E = 0.006363704597536102 (Model 0)
# Estd = 0.02773228023678459 (Model 0)
# F = 0.1283819266617963 (Model 0)
# Fstd = 0.01612787707591577 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.006363704597536102
# Estd = 0.02773228023678459
# Fmax = 0.1283819266617963
# Fstd = 0.01612787707591577
#
# Step 39: Model not trained.
#
#
# ============================ Step: 40 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (1.2196354866027832 s)
# Predict energy_uncertainty (0.7318363189697266 s)
# Predict forces (1.9046730995178223 s)
# Predict forces_uncertainty (2.595837116241455 s)
# E = 0.007662210884409992 (Model 0)
# Estd = 0.02782427597928983 (Model 0)
# F = 0.13237124949978385 (Model 0)
# Fstd = 0.017199711070571267 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.007662210884409992
# Estd = 0.02782427597928983
# Fmax = 0.13237124949978385
# Fstd = 0.017199711070571267
#
# Step 40: Model not trained.
#
#
# ============================ Step: 41 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.6517198085784912 s)
# Predict energy_uncertainty (0.46108436584472656 s)
# Predict forces (2.4540460109710693 s)
# Predict forces_uncertainty (2.274695634841919 s)
# E = 0.009009213518098469 (Model 0)
# Estd = 0.02792715272845535 (Model 0)
# F = 0.1362221197873033 (Model 0)
# Fstd = 0.01833651952112806 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.009009213518098469
# Estd = 0.02792715272845535
# Fmax = 0.1362221197873033
# Fstd = 0.01833651952112806
#
# Step 41: Model not trained.
#
#
# ============================ Step: 42 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.48344898223876953 s)
# Predict energy_uncertainty (0.5332682132720947 s)
# Predict forces (1.9509732723236084 s)
# Predict forces_uncertainty (2.722166061401367 s)
# E = 0.01039542942307603 (Model 0)
# Estd = 0.02804244024213922 (Model 0)
# F = 0.1400518235302594 (Model 0)
# Fstd = 0.01954653336267564 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.01039542942307603
# Estd = 0.02804244024213922
# Fmax = 0.1400518235302594
# Fstd = 0.01954653336267564
#
# Step 42: Model not trained.
#
#
# ============================ Step: 43 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.45364809036254883 s)
# Predict energy_uncertainty (0.6040668487548828 s)
# Predict forces (1.752995491027832 s)
# Predict forces_uncertainty (2.7471601963043213 s)
# E = 0.01182141303583506 (Model 0)
# Estd = 0.028164523878973047 (Model 0)
# F = 0.1440007908908402 (Model 0)
# Fstd = 0.020772976460065023 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.01182141303583506
# Estd = 0.028164523878973047
# Fmax = 0.1440007908908402
# Fstd = 0.020772976460065023
#
# Step 43: Model not trained.
#
#
# ============================ Step: 44 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.492260217666626 s)
# Predict energy_uncertainty (0.4829239845275879 s)
# Predict forces (1.676988124847412 s)
# Predict forces_uncertainty (3.467194080352783 s)
# E = 0.013289177047152045 (Model 0)
# Estd = 0.028296953653349652 (Model 0)
# F = 0.14792860558595847 (Model 0)
# Fstd = 0.022030262018755745 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.013289177047152045
# Estd = 0.028296953653349652
# Fmax = 0.14792860558595847
# Fstd = 0.022030262018755745
#
# Step 44: Model not trained.
#
#
# ============================ Step: 45 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.9663875102996826 s)
# Predict energy_uncertainty (1.2533702850341797 s)
# Predict forces (2.0426077842712402 s)
# Predict forces_uncertainty (1.9752097129821777 s)
# E = 0.014805509557957675 (Model 0)
# Estd = 0.028439201822778225 (Model 0)
# F = 0.1516494964465735 (Model 0)
# Fstd = 0.023399574582882585 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.014805509557957675
# Estd = 0.028439201822778225
# Fmax = 0.1516494964465735
# Fstd = 0.023399574582882585
#
# Step 45: Model not trained.
#
#
# ============================ Step: 46 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.6118109226226807 s)
# Predict energy_uncertainty (0.5979835987091064 s)
# Predict forces (1.4351415634155273 s)
# Predict forces_uncertainty (2.4573440551757812 s)
# E = 0.016342384733057824 (Model 0)
# Estd = 0.028589354335581293 (Model 0)
# F = 0.1558288123302067 (Model 0)
# Fstd = 0.024941113013550325 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.016342384733057824
# Estd = 0.028589354335581293
# Fmax = 0.1558288123302067
# Fstd = 0.024941113013550325
#
# Step 46: Model not trained.
#
#
# ============================ Step: 47 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.7920889854431152 s)
# Predict energy_uncertainty (0.9338226318359375 s)
# Predict forces (1.6386325359344482 s)
# Predict forces_uncertainty (3.2525758743286133 s)
# E = 0.01794513938503528 (Model 0)
# Estd = 0.028755738222923447 (Model 0)
# F = 0.1599679234985583 (Model 0)
# Fstd = 0.026568018242008745 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.01794513938503528
# Estd = 0.028755738222923447
# Fmax = 0.1599679234985583
# Fstd = 0.026568018242008745
#
# Step 47: Model not trained.
#
#
# ============================ Step: 48 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.8286504745483398 s)
# Predict energy_uncertainty (0.7275347709655762 s)
# Predict forces (2.190035104751587 s)
# Predict forces_uncertainty (2.3100666999816895 s)
# E = 0.019623823669929208 (Model 0)
# Estd = 0.028939823847435372 (Model 0)
# F = 0.1642867238799033 (Model 0)
# Fstd = 0.028376687463179773 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.019623823669929208
# Estd = 0.028939823847435372
# Fmax = 0.1642867238799033
# Fstd = 0.028376687463179773
#
# Step 48: Model not trained.
#
#
# ============================ Step: 49 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.9681174755096436 s)
# Predict energy_uncertainty (0.7148122787475586 s)
# Predict forces (2.150754451751709 s)
# Predict forces_uncertainty (2.741246461868286 s)
# E = 0.021367993402615748 (Model 0)
# Estd = 0.029138187822293625 (Model 0)
# F = 0.16841668580763422 (Model 0)
# Fstd = 0.030265800845633996 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.021367993402615748
# Estd = 0.029138187822293625
# Fmax = 0.16841668580763422
# Fstd = 0.030265800845633996
#
# Step 49: Model not trained.
#
#
# ============================ Step: 50 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.7754335403442383 s)
# Predict energy_uncertainty (0.6974022388458252 s)
# Predict forces (2.1757309436798096 s)
# Predict forces_uncertainty (2.3478574752807617 s)
# E = 0.02313002137255482 (Model 0)
# Estd = 0.029350288292188283 (Model 0)
# F = 0.17239118991504096 (Model 0)
# Fstd = 0.03214467082489204 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.02313002137255482
# Estd = 0.029350288292188283
# Fmax = 0.17239118991504096
# Fstd = 0.03214467082489204
#
# Step 50: Model not trained.
#
#
# ============================ Step: 51 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.5069572925567627 s)
# Predict energy_uncertainty (0.5394575595855713 s)
# Predict forces (1.4435021877288818 s)
# Predict forces_uncertainty (1.8573222160339355 s)
# E = 0.024934613275987783 (Model 0)
# Estd = 0.02957702515649926 (Model 0)
# F = 0.17651907602685626 (Model 0)
# Fstd = 0.03408705561839859 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.024934613275987783
# Estd = 0.02957702515649926
# Fmax = 0.17651907602685626
# Fstd = 0.03408705561839859
#
# Step 51: Model not trained.
#
#
# ============================ Step: 52 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.49613451957702637 s)
# Predict energy_uncertainty (0.4501209259033203 s)
# Predict forces (1.5639615058898926 s)
# Predict forces_uncertainty (2.969845771789551 s)
# E = 0.02674933742181762 (Model 0)
# Estd = 0.029813668076469367 (Model 0)
# F = 0.18076419350166553 (Model 0)
# Fstd = 0.03609551165752652 (Model 0)
#
# Model 0 has the lowest uncertainty.
# E = 0.02674933742181762
# Estd = 0.029813668076469367
# Fmax = 0.18076419350166553
# Fstd = 0.03609551165752652
#
# Step 52: Model not trained.
#
#
# ============================ Step: 53 ============================
#
# Total structures in training data: 19
# Model 0...
# Predict energy (0.560260534286499 s)
# Predict energy_uncertainty (0.4879589080810547 s)

# %% [markdown]
# ## How Does Clustering Affect Performance?
#
# **Before running, predict:**
# - model_size = 100: faster or slower than no clustering?
# - model_size = 500: faster or slower than no clustering?
# - Which model_size gives the fastest simulation?
#
# Let's test.

# %%
# ============================================================
# SWEEP OVER MODEL SIZES
# ============================================================
model_sizes = [100, 200, 500, None]  # None = no clustering
results_ms = {}

for ms in model_sizes:
    label = f"size={ms}" if ms else "no clustering"
    print(f"\n{'='*50}")
    print(f"Running: {label}")
    print(f"{'='*50}")
    
    # Fresh structure
    atoms = bulk('Pt', 'fcc', a=3.92, cubic=True).repeat((3, 3, 3))
    exact_calc = EMT()
    atoms.calc = exact_calc
    
    # Optimize
    qn = QuasiNewton(atoms, trajectory=f'outputs/opt_ms{ms}.traj')
    qn.run(fmax=0.05)
    training_data = read(f'outputs/opt_ms{ms}.traj@0:1')
    
    # FALCON
    atoms.calc = FALCON(
        model=GPR(atoms),
        exact_calc=exact_calc,
        training_data=training_data,
        accuracy_e=0.10,
        model_size=ms
    )
    
    # Run
    n_steps_short = 3000
    t_start = time.time()
    
    dyn = Langevin(atoms, 1*units.fs, temperature_K=T, friction=0.002)
    for step in range(n_steps_short):
        dyn.run(1)
    
    t_total = time.time() - t_start
    n_train = len(atoms.calc.training_data)
    
    results_ms[label] = {
        'n_train': n_train,
        'time': t_total,
    }
    
    print(f"  Training structures: {n_train}")
    print(f"  Total time: {t_total:.1f} s")

# ============================================================
# PLOT RESULTS
# ============================================================
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

labels = list(results_ms.keys())
n_trains = [results_ms[l]['n_train'] for l in labels]
times = [results_ms[l]['time'] for l in labels]

axes[0].bar(labels, n_trains, color='steelblue')
axes[0].set_ylabel('Training structures', fontsize=12)
axes[0].set_title('Training data volume', fontsize=14)
axes[0].tick_params(axis='x', rotation=45)

axes[1].bar(labels, times, color='coral')
axes[1].set_ylabel('Total wall time (s)', fontsize=12)
axes[1].set_title('Simulation time', fontsize=14)
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig('outputs/model_size_sweep.png', dpi=150)
plt.show()

print("\nSummary:")
for label in labels:
    print(f"  {label:15s} → {results_ms[label]['n_train']} structures, "
          f"{results_ms[label]['time']:.1f} s")

# %% [markdown]
# ## Watching FALCON Learn in Real Time
#
# Let's run a shorter simulation with a live-updating plot.
#
# This shows the active learning process as it happens.

# %%
# ============================================================
# REAL-TIME PLOT (works in Jupyter)
# ============================================================
from IPython.display import display, clear_output

# Setup
atoms = bulk('Pt', 'fcc', a=3.92, cubic=True).repeat((3, 3, 3))
exact_calc = EMT()
atoms.calc = exact_calc

qn = QuasiNewton(atoms, trajectory='outputs/opt_live.traj')
qn.run(fmax=0.05)
training_data = read('outputs/opt_live.traj@0:1')

atoms.calc = FALCON(
    model=GPR(atoms),
    exact_calc=exact_calc,
    training_data=training_data,
    accuracy_e=0.10,
    model_size=200
)

dyn = Langevin(atoms, 1*units.fs, temperature_K=T, friction=0.002)

# Live plot
fig, axes = plt.subplots(2, 1, figsize=(10, 6))
energies_live = []
n_train_live = []

for step in range(2000):
    dyn.run(1)
    energies_live.append(atoms.get_potential_energy())
    n_train_live.append(len(atoms.calc.training_data))
    
    if step % 100 == 0:
        clear_output(wait=True)
        
        axes[0].clear()
        axes[0].plot(energies_live, 'r-', alpha=0.6)
        axes[0].set_ylabel('Energy (eV)')
        axes[0].set_title(f'Step {step}: E = {energies_live[-1]:.3f} eV')
        
        axes[1].clear()
        axes[1].plot(n_train_live, 'b-', linewidth=2)
        axes[1].set_ylabel('Training structures')
        axes[1].set_xlabel('MD step')
        axes[1].set_title(f'Training data: {n_train_live[-1]} structures')
        
        plt.tight_layout()
        display(fig)
        plt.close()

print(f"\nFinal: {n_train_live[-1]} training structures")

# %% [markdown]
# ## Is My Simulation Healthy?
#
# Not every FALCON run goes smoothly. Here's how to diagnose problems.

# %%
# ============================================================
# HEALTH CHECK
# ============================================================
def diagnose_falcon(atoms, energies, n_training):
    E_std = np.std(energies)
    E_drift = abs(np.mean(energies[-100:]) - np.mean(energies[:100]))

    print("\n1. Energy stability:")
    print(f"   Energy std:   {E_std:.4f} eV")
    print(f"   Energy drift: {E_drift:.4f} eV")
    print("   WARNING: significant energy drift!" if E_drift > 0.1 else "   Energy is stable")

    n_final = n_training[-1]
    n_growth = n_training[-1] - n_training[len(n_training) // 2]
    print("\n2. Training data growth:")
    print(f"   Final training structures: {n_final}")
    print(f"   Growth in second half:     {n_growth}")
    if n_growth > n_final * 0.5:
        print("   WARNING: training data still growing rapidly — model may not have converged")
        print("   Consider increasing ε or running longer")
    else:
        print("   Training data has stabilized")

    print("\n3. System health:")
    pos = atoms.get_positions()
    max_disp = np.max(np.linalg.norm(pos - pos.mean(axis=0), axis=1))
    print(f"   Number of atoms: {len(atoms)}")
    print(f"   Max atomic displacement from center: {max_disp:.2f} Å")
    print("   WARNING: atoms may have evaporated!" if max_disp > 15 else "   System is intact")

# Run diagnosis
diagnose_falcon(atoms, energies, n_training_at_step)

# %% [markdown]
# ## From Pt₅₅ to Li₃OCl/Br
#
# The Pt₅₅ demo is simple: one element, no electrostatics, no defects.
#
# Your system is harder: five elements, ionic, defect-rich.
#
# ### What Changes
#
# | Feature | Pt₅₅ Demo | Li₃OCl/Br |
# |:---|:---|:---|
# | **Elements** | 1 (Pt) | 5 (Li, O, Cl, Br, Al) |
# | **Electrostatics** | None | Strong (ionic conductor) |
# | **Defects** | None | Vacancies, interstitials, cascades |
# | **Training data** | 1 optimized structure | 50-100 DFT frames |
# | **Exact calculator** | EMT (milliseconds) | VASP/QE (minutes to hours) |
# | **Accuracy threshold** | 0.10 eV | 0.05-0.10 eV |
# | **Model size** | 200 | 200-500 |
#
# ### The Adaptation Workflow
#
# 1. Prepare initial training data
# training_data = read('li3oclbr_pristine.traj')  # 50-100 DFT frames
#
# 2. FALCON setup with DFT as exact calculator
# ```
# from ase.calculators.vasp import Vasp
# exact_calc = Vasp(...)  # Your DFT settings
#
# atoms.calc = FALCON(
#     model=GPR(atoms),
#     exact_calc=exact_calc,
#     training_data=training_data,
#     accuracy_e=0.10,
#     model_size=300  # Larger for multi-element systems
# )
# ```
#
# 3. Run short OTF-MD at 600 K
# 4. Post-process to find uncertain structures
# 5. Add them to DFT training set
# 6. Train MACE for production

# %% [markdown]
# ## Summary: What We Just Did
#
# | Experiment | What We Learned |
# |:---|:---|
# | **Baseline run** | Training data grows rapidly, then plateaus |
# | **ε sweep** | Lower ε → more DFT calls, longer simulation |
# | **model_size sweep** | Clustering beats no clustering; 200 is optimal for Pt₅₅ |
# | **Real-time plot** | Active learning is fast then confident |
# | **Health check** | Energy drift and training growth diagnose problems |
# | **Li₃OCl/Br adaptation** | More elements, more DFT, more care |
#
# ## The Complete Workshop So Far
# Part 0: Setup
#
# Part 1a: Built a neuron
#
# Part 1b: Computed forces via autograd
#
# Part 1c: Trained a NN potential
#
# Part 2: Understood FALCON architecture
#
# Part 3: Ran FALCON and analyzed results ← WE ARE HERE
#
# ## Next: Part 4 — Clustering Deep Dive
#
# In Part 4, we'll:
# 1. Extract the training data from our FALCON run
# 2. Cluster it with SOAP descriptors
# 3. Visualize the PES regions
# 4. Understand which configurations matter most
